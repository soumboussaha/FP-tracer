# %% [markdown]
# ## Preparation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import glob
import os
from common import *

plt.style.use('thesis.mplstyle')

# %%
thousandsGroupingFormatter =  mpl.ticker.FuncFormatter(lambda x, p: '$'+format(int(x), ',').replace(',', '\,')+'$')

# %%
from pandas import Series


def otherSeries(seriesToBeOthered:Series, valuesToKeep:int):
    seriesToBeOthered_value_counts = seriesToBeOthered.value_counts()
    min_val = seriesToBeOthered_value_counts[valuesToKeep]
    keep_vals = seriesToBeOthered_value_counts[seriesToBeOthered_value_counts>min_val]
    otheredSeries = seriesToBeOthered.copy()
    otheredSeries[~(otheredSeries.isin(keep_vals.index))] = 'other'
    return otheredSeries

# %% [markdown]
# ## Load and Combine Data

# %%
results = pd.read_json('crawl_results_filter/results.json').astype({'hasBanner':'bool'})

# path = r'crawl_results_filter'
# pattern = r'results.json_*'
# all_files = glob.glob(os.path.join(path ,pattern))
# li = []
# for filename in all_files:
#     df = pd.read_json(filename).astype({'hasBanner':'bool'})
#     li.append(df)
# results = pd.concat(li, axis=0, ignore_index=True)

results
# Out:
#                 pageUrl                  usedUrl  \
# 0            google.com       https://google.com
# 1      gtld-servers.net                      NaN
# 2        akamaiedge.net                      NaN
# 3          facebook.com     https://facebook.com
# 4           netflix.com      https://netflix.com
# ...                 ...                      ...
# 99995    chartmogul.com   https://chartmogul.com
# 99996        sfmlab.com       https://sfmlab.com
# 99997       shou.edu.cn  https://www.shou.edu.cn
# 99998           bart.nl       http://www.bart.nl
# 99999    blogpeople.net                      NaN
#
#                               fullUrl  hasBanner             cmp  \
# 0             https://www.google.com/       True    google_popup
# 1                                 NaN       True             NaN
# 2                                 NaN       True             NaN
# 3           https://www.facebook.com/       True        Facebook
# 4      https://www.netflix.com/de-en/       True  onetrust_pctab
# ...                               ...        ...             ...
# 99995         https://chartmogul.com/      False             NaN
# 99996             https://sfmlab.com/      False             NaN
# 99997        https://www.shou.edu.cn/      False             NaN
# 99998              http://www.iae.nl/      False             NaN
# 99999                             NaN       True             NaN
#
#                                                    error
# 0                                                    NaN
# 1      Could not reach Url with any alternative. Erro...
# 2      Could not reach Url with any alternative. Erro...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 99995                                                NaN
# 99996                                                NaN
# 99997                                                NaN
# 99998                                                NaN
# 99999  Could not reach Url with any alternative. Erro...
#
# [100000 rows x 6 columns]

# %%
tranco = pd.read_csv('tranco_top-1m_N7QVW_2022-10-07.csv',names=['pagerank','domain'])
tranco
# Out:
#         pagerank                 domain
# 0              1             google.com
# 1              2       gtld-servers.net
# 2              3            youtube.com
# 3              4           facebook.com
# 4              5          microsoft.com
# ...          ...                    ...
# 999995    999996  migrationinstitute.fi
# 999996    999997             cobourg.ca
# 999997    999998             dtyxjd.com
# 999998    999999            uitv.com.cn
# 999999   1000000      orvilleandrea.pro
#
# [1000000 rows x 2 columns]

# %%
results = results.merge(tranco,how='left',left_on='pageUrl',right_on='domain').drop(columns='domain')
results
# Out:
#                 pageUrl                  usedUrl  \
# 0            google.com       https://google.com
# 1      gtld-servers.net                      NaN
# 2        akamaiedge.net                      NaN
# 3          facebook.com     https://facebook.com
# 4           netflix.com      https://netflix.com
# ...                 ...                      ...
# 99995    chartmogul.com   https://chartmogul.com
# 99996        sfmlab.com       https://sfmlab.com
# 99997       shou.edu.cn  https://www.shou.edu.cn
# 99998           bart.nl       http://www.bart.nl
# 99999    blogpeople.net                      NaN
#
#                               fullUrl  hasBanner             cmp  \
# 0             https://www.google.com/       True    google_popup
# 1                                 NaN       True             NaN
# 2                                 NaN       True             NaN
# 3           https://www.facebook.com/       True        Facebook
# 4      https://www.netflix.com/de-en/       True  onetrust_pctab
# ...                               ...        ...             ...
# 99995         https://chartmogul.com/      False             NaN
# 99996             https://sfmlab.com/      False             NaN
# 99997        https://www.shou.edu.cn/      False             NaN
# 99998              http://www.iae.nl/      False             NaN
# 99999                             NaN       True             NaN
#
#                                                    error  pagerank
# 0                                                    NaN         1
# 1      Could not reach Url with any alternative. Erro...         2
# 2      Could not reach Url with any alternative. Erro...         6
# 3                                                    NaN         4
# 4                                                    NaN         7
# ...                                                  ...       ...
# 99995                                                NaN     99997
# 99996                                                NaN    100000
# 99997                                                NaN     99984
# 99998                                                NaN     99988
# 99999  Could not reach Url with any alternative. Erro...     99998
#
# [100000 rows x 7 columns]

# %%
results[results.pageUrl=='carrefour.es']
# Out:
#             pageUrl               usedUrl                    fullUrl  \
# 19584  carrefour.es  https://carrefour.es  https://www.carrefour.es/
#
#        hasBanner              cmp error  pagerank
# 19584       True  onetrust_banner   NaN     19586

# %% [markdown]
# ## Find missing Websites

# %%
missing = tranco[~(tranco.domain.isin(results.pageUrl))]
missing
# Out:
#         pagerank                    domain
# 100000    100001                    unt.se
# 100001    100002              usheethe.com
# 100002    100003                  coach.me
# 100003    100004  sdzwildlifeexplorers.org
# 100004    100005            epaenlinea.com
# ...          ...                       ...
# 999995    999996     migrationinstitute.fi
# 999996    999997                cobourg.ca
# 999997    999998                dtyxjd.com
# 999998    999999               uitv.com.cn
# 999999   1000000         orvilleandrea.pro
#
# [900000 rows x 2 columns]

# %%
# count missing domains
missing.shape[0]
# Out:
# 900000

# %% [markdown]
# ## Sites with Strange Redirects

# %%
# results.dtypes

# %%
# results.loc[~(results.fullUrl.isna()),'urlMatch'] = results[~(results.fullUrl.isna())].apply(func = (lambda r: (r.pageUrl in r.fullUrl)  ), axis='columns')
# results.loc[results.urlMatch == False,['pagerank','pageUrl','usedUrl','fullUrl']]

# %%
# results.loc[((results.urlMatch == False) & (results.fullUrl.str.len()>500)),['pagerank','pageUrl','usedUrl','fullUrl']]

# %% [markdown]
# ## Create URL-List for Fingerprinting Detection Crawl

# %%
results.loc[(~(results.fullUrl.isna())) & (results.hasBanner),'pageUrl'].to_csv('tranco_top-100k_N7QVW_2022-10-07_with_cmp',index=False,header=False)

# %% [markdown]
# ## Process findings

# %%
results['reached'] = ~(results.fullUrl.isna())

results['status'] = None
results.loc[~(results.reached),'status'] = 'not reached'
results.loc[(results.reached)&(results.hasBanner),'status'] = 'compatible CMP detected'
results.loc[(results.reached)&(~(results.hasBanner)),'status'] = 'no CMP detected'
results['rank_group']=pd.cut(results.pagerank,bins=rank_group_bins)


results['cmp_simplified'] = results.cmp
results.loc[(~(results.cmp.isna())) & (results.cmp.str.startswith('trustarc')),'cmp_simplified'] = 'trustarc'
results.loc[(~(results.cmp.isna())) & (results.cmp.str.startswith('onetrust')),'cmp_simplified'] = 'onetrust'
results.loc[(~(results.cmp.isna())) & (results.cmp.str.startswith('sourcepoint')),'cmp_simplified'] = 'sourcepoint'
results.loc[(~(results.cmp.isna())) & (results.cmp.str.startswith('yahoo')),'cmp_simplified'] = 'yahoo'
results.loc[(~(results.cmp.isna())) & (results.cmp.str.startswith('Evidon')),'cmp_simplified'] = 'Evidon'
results.loc[(~(results.cmp.isna())) & (results.cmp.str.startswith('cookieinformation')),'cmp_simplified'] = 'cookieinformation'
results.loc[(~(results.cmp.isna())) & (results.cmp.str.startswith('quantcast')),'cmp_simplified'] = 'quantcast'
results.loc[(~(results.cmp.isna())) & (results.cmp.str.startswith('paypal')),'cmp_simplified'] = 'paypal'
results.loc[(~(results.cmp.isna())) & (results.cmp.str.startswith('cookieinformation')),'cmp_simplified'] = 'cookieinformation'
results.loc[(~(results.cmp.isna())) & (results.cmp.str.startswith('google')),'cmp_simplified'] = 'google'
results.loc[(~(results.cmp.isna())) & (results.cmp.str.startswith('bbc_fc')),'cmp_simplified'] = 'funding choices'

cmp_simplified_value_counts = results.cmp_simplified.value_counts()
min_cmp = cmp_simplified_value_counts[7]
keep_cmps = cmp_simplified_value_counts[cmp_simplified_value_counts>min_cmp]
results['cmp_simplified_othered'] = results.cmp_simplified
results.loc[(~(results.cmp_simplified.isna())) & ~(results.cmp_simplified.isin(keep_cmps.index)),'cmp_simplified_othered'] = 'other'

results['tld']=results.pageUrl.str.split('.').str[-1]
results['tld_othered']=otherSeries(results.tld,14)

results
# Out:
#                 pageUrl                  usedUrl  \
# 0            google.com       https://google.com
# 1      gtld-servers.net                      NaN
# 2        akamaiedge.net                      NaN
# 3          facebook.com     https://facebook.com
# 4           netflix.com      https://netflix.com
# ...                 ...                      ...
# 99995    chartmogul.com   https://chartmogul.com
# 99996        sfmlab.com       https://sfmlab.com
# 99997       shou.edu.cn  https://www.shou.edu.cn
# 99998           bart.nl       http://www.bart.nl
# 99999    blogpeople.net                      NaN
#
#                               fullUrl  hasBanner             cmp  \
# 0             https://www.google.com/       True    google_popup
# 1                                 NaN       True             NaN
# 2                                 NaN       True             NaN
# 3           https://www.facebook.com/       True        Facebook
# 4      https://www.netflix.com/de-en/       True  onetrust_pctab
# ...                               ...        ...             ...
# 99995         https://chartmogul.com/      False             NaN
# 99996             https://sfmlab.com/      False             NaN
# 99997        https://www.shou.edu.cn/      False             NaN
# 99998              http://www.iae.nl/      False             NaN
# 99999                             NaN       True             NaN
#
#                                                    error  pagerank  reached  \
# 0                                                    NaN         1     True
# 1      Could not reach Url with any alternative. Erro...         2    False
# 2      Could not reach Url with any alternative. Erro...         6    False
# 3                                                    NaN         4     True
# 4                                                    NaN         7     True
# ...                                                  ...       ...      ...
# 99995                                                NaN     99997     True
# 99996                                                NaN    100000     True
# 99997                                                NaN     99984     True
# 99998                                                NaN     99988     True
# 99999  Could not reach Url with any alternative. Erro...     99998    False
#
#                         status       rank_group cmp_simplified  \
# 0      compatible CMP detected       (0, 10000]         google
# 1                  not reached       (0, 10000]            NaN
# 2                  not reached       (0, 10000]            NaN
# 3      compatible CMP detected       (0, 10000]       Facebook
# 4      compatible CMP detected       (0, 10000]       onetrust
# ...                        ...              ...            ...
# 99995          no CMP detected  (90000, 100000]            NaN
# 99996          no CMP detected  (90000, 100000]            NaN
# 99997          no CMP detected  (90000, 100000]            NaN
# 99998          no CMP detected  (90000, 100000]            NaN
# 99999              not reached  (90000, 100000]            NaN
#
#       cmp_simplified_othered  tld tld_othered
# 0                     google  com         com
# 1                        NaN  net         net
# 2                        NaN  net         net
# 3                      other  com         com
# 4                   onetrust  com         com
# ...                      ...  ...         ...
# 99995                    NaN  com         com
# 99996                    NaN  com         com
# 99997                    NaN   cn          cn
# 99998                    NaN   nl       other
# 99999                    NaN  net         net
#
# [100000 rows x 14 columns]

# %% [markdown]
# # Create Status List for Detection Analysis

# %%
results[['pageUrl','status']].rename(columns={'pageUrl':'domain'}).to_csv('filterCrawlStatusReport.csv',index=False,header=True)

# %% [markdown]
# # Access Scheme Analysis

# %%
def getAccessScheme(resultRow: pd.Series):
    if resultRow.reached == False:
        return 'unreachable'
    else:
        return resultRow.usedUrl[0:len(resultRow.usedUrl)-len(resultRow.pageUrl)]

results['accessScheme'] = results.apply(getAccessScheme,axis=1)
results.accessScheme.value_counts()
# Out:
# https://        72377
# unreachable     13310
# http://          9637
# https://www.     3150
# http://www.      1526
# Name: accessScheme, dtype: int64

# %% [markdown]
# # Fix Wrong Status Tagging

# %%
wronglyTaggedDomains = results.loc[(results.status=='compatible CMP detected') & (results.cmp.isna()),'pageUrl']
wronglyTaggedDomains.to_csv('filterCrawlWronglyTaggedAsWithCmp.csv',index=False,header=True)
print(f'Number of domains wrongly tagged as [with CMP]:    {wronglyTaggedDomains.shape[0]}')
withCmpCountBefore = results.loc[(results.status=='compatible CMP detected')].shape[0]
print(f'Number of domains tagged as [with CMP] before fix: {withCmpCountBefore}')
results.loc[(results.status=='compatible CMP detected') & (results.cmp.isna()),'status'] = 'no CMP detected'
withCmpCountAfter = results.loc[(results.status=='compatible CMP detected')].shape[0]
print(f'Number of domains tagged as [with CMP] after fix: {withCmpCountAfter}')
# Out:
# Number of domains wrongly tagged as [with CMP]:    2710
# Number of domains tagged as [with CMP] before fix: 11957
# Number of domains tagged as [with CMP] after fix: 9247

# %% [markdown]
# # Analyze Findings

# %% [markdown]
# ### Status Overview

# %%
results.groupby('cmp_simplified').pageUrl.agg(lambda x: ','.join(x[0:10]))
# Out:
# cmp_simplified
# Autodesk               instructables.com,plangrid.com,autodesk360.com...
# Evidon                 dropbox.com,playstation.com,ge.com,fujitsu.com...
# Facebook               facebook.com,fbcdn.net,fb.com,fb.me,messenger....
# Fanatical                                                  fanatical.com
# SFR                                         sfr.fr,neuf.fr,red-by-sfr.fr
# Sirdata                dafont.com,joemonster.org,forocoches.com,alete...
# Truendo                formstack.com,sportradar.com,sportradarserving...
# Twitter                twitter.com,sv.com,isna.ir,malc.org.uk,twiter....
# Volkswagen                                       vw.com,volkswagen.co.uk
# Webedia                elcomercio.pe,ultimateclassicrock.com,mangahas...
# begadi.com             delta.com,managewp.com,ku.edu.tr,bequiet.com,a...
# consentmanager.net     mail.ru,sourceforge.net,slashdot.org,funkedigi...
# cookieLab                                         christianlouboutin.com
# cookiebar              smartadserver.com,libsyn.com,adotmob.com,catch...
# cookiebot              issuu.com,kaspersky.com,kaspersky-labs.com,lau...
# cookiecontrolcivic     intermedia.net,ico.org.uk,msi.com,amnesty.org,...
# cookieinformation      simply.com,dandomain.dk,tele.dk,aau.dk,wannafi...
# cookiescript           veeam.com,zyxel.com,winamp.com,dtu.dk,juicyads...
# danskebank                                                danskebank.com
# designilpdpa                                                 chula.ac.th
# didomi.io              free.fr,marca.com,reverso.net,softonic.com,fra...
# ez-cookie              smallbiztrends.com,simplypsychology.org,scitec...
# funding choices        bbc.co.uk,bbc.com,hbr.org,accuweather.com,eksi...
# google                 google.com,youtube.com,youtu.be,googlevideo.co...
# ibuenda                altervista.org,repubblica.it,elastic.co,iubend...
# oil                    rai.it,raiplay.it,tdg.ch,rai.tv,tio.ch,destini...
# onetrust               netflix.com,cloudflare.com,fastly.net,vimeo.co...
# optanon                springer.com,blizzard.com,lonelyplanet.com,tru...
# optanon-alternative                                            icr.ac.uk
# paypal                                               paypal.com,xoom.com
# pricerunnerdk                                             pricerunner.dk
# quantcast              fandom.com,researchgate.net,huffingtonpost.com...
# sfbx_appconsent        lefigaro.fr,linternaute.com,viadeo.com,comment...
# sourcepoint            theguardian.com,bloomberg.com,wsj.com,business...
# springer               onet.pl,blick.ch,businessinsider.com.pl,fakt.p...
# tealium.com            huawei.com,hulu.com,economist.com,swisscom.com...
# trustarc               flickr.com,forbes.com,linode.com,oracle.com,al...
# uniconsent             sharethrough.com,dealmoon.com,uniconsent.com,h...
# yahoo                  yahoo.com,att.net,aol.com,techcrunch.com,engad...
# Name: pageUrl, dtype: object

# %%
status_counts = results.status.value_counts()
fig, ax = plt.subplots()

def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '{p:.2f}%  ({v:d})'.format(p=pct,v=val)
    return my_autopct

status_counts.plot(
    kind='pie',
    ax = ax,
    autopct=make_autopct(status_counts)
)
saveFigure(fig,'filter_scan_status')
plt.show()

# %% [markdown]
# ### Frequent CMPs

# %%
cmp_counts = results.loc[results.hasBanner,'cmp_simplified'].value_counts()
fig, ax = plt.subplots()
fig.set_figheight(8)
cmp_counts.plot(
    kind='barh',
    ax=ax,
    logx=True
)
ax.bar_label(ax.containers[0])

ax.set_xlabel('website count')
ax.set_ylabel('consent management platform')

saveFigure(fig,'filter_scan_cmps')
plt.show()

# %% [markdown]
# ### Frequent TLDs

# %%
tld_counts = results.tld_othered.value_counts()
fig, ax = plt.subplots()
fig.set_figheight(3)
tld_counts.plot(
    kind='barh',
    ax=ax
)
ax.bar_label(ax.containers[0])

ax.set_xlabel('website count')
ax.set_ylabel('top level domain')

ax.set_xlim(0,55000)

saveFigure(fig,'filter_scan_tlds')
plt.show()

# %% [markdown]
# ### Status at Ranks

# %%
status_at_ranks = results.pivot_table(index=['rank_group'],columns=['status'],aggfunc={'pageUrl':'count'})
status_at_ranks
# Out:
#                                 pageUrl
# status          compatible CMP detected no CMP detected not reached
# rank_group
# (0, 10000]                         1540            6757        1703
# (10000, 20000]                     1210            7423        1367
# (20000, 30000]                     1080            7545        1375
# (30000, 40000]                      908            7799        1293
# (40000, 50000]                      882            7838        1280
# (50000, 60000]                      838            7870        1292
# (60000, 70000]                      741            7916        1343
# (70000, 80000]                      708            8082        1210
# (80000, 90000]                      681            8066        1253
# (90000, 100000]                     659            8147        1194

# %%
fig, ax = plt.subplots()
status_at_ranks.plot(
    ax=ax,
    kind='bar',
    stacked=True
)

fig.set_figheight(2.5)

handles = ax.get_legend_handles_labels()
ax.legend(
    reversed(handles[0]),
    reversed([c[1] for c in  status_at_ranks.columns]),
    title='status in filter crawl',
    loc='center left',
    bbox_to_anchor=(1.02, 0.5),
    ncol=1
    )

ax.set_ylabel('website count')
ax.set_xlabel('Tranco rank')


ax.grid(
    visible=True,
    axis='y')
ax.set_axisbelow(True)

ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=35, ha='right')

ax.yaxis.set_major_formatter(thousandsGroupingFormatter)

ax.set_ylim(top=10000)


saveFigure(fig,'filter_scan_status_details')
plt.show()

# %% [markdown]
# ### Has Banner at Ranks

# %%
relative_status_n = status_at_ranks[('pageUrl','compatible CMP detected')] + status_at_ranks[('pageUrl','no CMP detected')]
relative_status = status_at_ranks\
    .divide(\
        relative_status_n,
        axis='rows')\
    .loc[:,[('pageUrl','compatible CMP detected'),('pageUrl','no CMP detected')]]

fig, ax = plt.subplots()
relative_status.plot(
    kind='bar',
    ax=ax
)

handles = ax.get_legend_handles_labels()
ax.legend(
    handles[0],
    [c[1] for c in  relative_status.columns],
    loc='lower center',
    bbox_to_anchor=(0.5, 1.02),
    ncol=2
    )

ax.set_ylim(0,1)

ax.set_ylabel('website fraction')
ax.set_xlabel('Tranco rank')


ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=35, ha='right')

ax.grid(
    visible=True,
    axis='y')
ax.set_axisbelow(True)

ax.bar_label(ax.containers[1],labels='n='+relative_status_n.astype('string'),padding=1)


plt.show()

# %%
relative_status = status_at_ranks\
    .divide(\
        status_at_ranks[('pageUrl','compatible CMP detected')] + status_at_ranks[('pageUrl','no CMP detected')],
        axis='rows')\
    .loc[:,[('pageUrl','compatible CMP detected'),('pageUrl','no CMP detected')]]\
    .loc[:,[('pageUrl','compatible CMP detected')]]


relative_status_n = status_at_ranks[('pageUrl','compatible CMP detected')] + status_at_ranks[('pageUrl','no CMP detected')]

fig, ax = plt.subplots()
relative_status.plot(
    kind='bar',
    ax=ax
)

handles = ax.get_legend_handles_labels()
ax.legend(
    handles[0],
    [c[1] for c in  relative_status.columns],
    loc='lower center',
    bbox_to_anchor=(0.5, 1.02),
    ncol=2
    )

ax.set_ylim(0,0.3)

ax.set_ylabel('website fraction')
ax.set_xlabel('Tranco rank')


ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=35, ha='right')

ax.grid(
    visible=True,
    axis='y')
ax.set_axisbelow(True)

ax.bar_label(ax.containers[0],labels='n='+relative_status_n.astype('string'),padding=5)


plt.show()

# %% [markdown]
# ### TLD Coverage

# %%
import importlib
import common
importlib.reload(common)
from common import *

# %%
status_at_tlds = results\
    .pivot_table(index=['tld_othered'],columns=['status'],aggfunc={'pageUrl':'count'})

relative_status_tlds = status_at_tlds\
    .divide(\
        status_at_tlds[('pageUrl','compatible CMP detected')] + status_at_tlds[('pageUrl','no CMP detected')],
        axis='rows')\
    .sort_values(by=('pageUrl','compatible CMP detected'))\
    .sort_index(axis='index',key=keyTldCategory)\
    .loc[:,[('pageUrl','compatible CMP detected'),('pageUrl','no CMP detected')]]\
    .loc[:,[('pageUrl','compatible CMP detected')]]


relative_status_tlds_n = (status_at_tlds[('pageUrl','compatible CMP detected')] + status_at_tlds[('pageUrl','no CMP detected')])\
    .sort_values()\
    .sort_index(key=keyTldCategory)\

fig, ax = plt.subplots()

fig.set_figheight(2.0)

barContainer = ax.bar(
    x = [a*1.1 for a in[1,2,3,4.5,5.5,6.5,7.5,9,10,11,12,13,14,15,16.5]],
    height=relative_status_tlds[('pageUrl','compatible CMP detected')],
    tick_label=relative_status_tlds.index,
    color=[getTldCategoryColor(i) for i in relative_status_tlds.index]
)


ax.legend(
    handles=tldCategoryHandles,
    loc='lower center',
    bbox_to_anchor=(0.5, 1.02),
    ncol=4
    )

# ax.set_ylim(0,0.55)
ax.set_ylim(top=0.40)

ax.set_ylabel('website fraction\nwith compatible CMP')
ax.set_xlabel('top-level domain')


ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=0, ha='center')

ax.grid(
    visible=True,
    axis='y')
ax.set_axisbelow(True)

ax.bar_label(ax.containers[0],labels='n='+relative_status_tlds_n.astype('string'),padding=2, rotation=0, size=6)

saveFigure(fig,'filter_scan_tld_details')
plt.show()

# %% [markdown]
# ### CMPs at Ranks

# %%
successfulDomainsAtRanks = results\
    .loc[results.status == 'compatible CMP detected','rank_group']\
    .value_counts()\
    .sort_index()
successfulDomainsAtRanks
# Out:
# (0, 10000]         1540
# (10000, 20000]     1210
# (20000, 30000]     1080
# (30000, 40000]      908
# (40000, 50000]      882
# (50000, 60000]      838
# (60000, 70000]      741
# (70000, 80000]      708
# (80000, 90000]      681
# (90000, 100000]     659
# Name: rank_group, dtype: int64

# %%
cmp_at_ranks = results\
    .loc[results.status == 'compatible CMP detected']\
    .pivot_table(index=['rank_group'],columns=['cmp_simplified_othered'],aggfunc={'pageUrl':'count'})\
    .sort_values(axis='columns',by=1, ascending=False)
other_column = cmp_at_ranks.pop(('pageUrl','other'))
cmp_at_ranks[('pageUrl','other')]=other_column

cmp_at_ranks = cmp_at_ranks.divide(
    successfulDomainsAtRanks,
    axis='rows'
)

# cmp_at_ranks.style\
#     .format_index(escape="latex", axis=1, level=0)\
#     .format_index(escape="latex", axis=1, level=1)\
#     .format_index(escape="latex", axis=0, level=0)\
#     .format_index(escape="latex", axis=0, level=1)\
#     .hide(level=0, axis=0)\
#     .hide(level=0, axis=1)\
#     .to_latex('tables/cmp_at_ranks.tex',hrules=True,multicol_align='c',siunitx=True)


cmp_at_ranks
# Out:
#                          pageUrl                                            \
# cmp_simplified_othered  onetrust    google sourcepoint  trustarc quantcast
# rank_group
# (0, 10000]              0.507143  0.094805    0.073377  0.065584  0.064935
# (10000, 20000]          0.436364  0.107438    0.053719  0.042975  0.077686
# (20000, 30000]          0.468519  0.013889    0.078704  0.049074  0.095370
# (30000, 40000]          0.426211  0.016520    0.062775  0.040749  0.112335
# (40000, 50000]          0.437642  0.015873    0.073696  0.043084  0.104308
# (50000, 60000]          0.418854  0.021480    0.091885  0.023866  0.089499
# (60000, 70000]          0.400810  0.017544    0.068826  0.039136  0.102564
# (70000, 80000]          0.381356  0.016949    0.079096  0.040960  0.103107
# (80000, 90000]          0.386197  0.011747    0.058737  0.041116  0.107195
# (90000, 100000]         0.394537  0.019727    0.084977  0.040971  0.124431
#
#
# cmp_simplified_othered cookiebot funding choices     other
# rank_group
# (0, 10000]              0.040260        0.033766  0.120130
# (10000, 20000]          0.068595        0.046281  0.166942
# (20000, 30000]          0.069444        0.048148  0.176852
# (30000, 40000]          0.080396        0.064978  0.196035
# (40000, 50000]          0.088435        0.039683  0.197279
# (50000, 60000]          0.102625        0.051313  0.200477
# (60000, 70000]          0.103914        0.058030  0.209177
# (70000, 80000]          0.115819        0.067797  0.194915
# (80000, 90000]          0.099853        0.051395  0.243759
# (90000, 100000]         0.098634        0.044006  0.192716

# %%
fig, ax = plt.subplots()
cmp_at_ranks.plot(
    ax=ax,
    kind='bar',
    stacked=True
)

fig.set_figheight(2.5)

handles = ax.get_legend_handles_labels()
ax.legend(
    reversed(handles[0]),
    reversed([c[1] for c in  cmp_at_ranks.columns]),
    title='consent\nmanagement\nplatform',
    loc='upper left',
    bbox_to_anchor=(1.02, 1.0),
    ncol=1
    )

ax.set_ylabel('fraction of\nsuccessful websites')
ax.set_xlabel('Tranco rank')


ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=35, ha='right')

ax.grid(
    visible=True,
    axis='y')
ax.set_axisbelow(True)

# ax.yaxis.set_major_formatter(thousandsGroupingFormatter)

# ax.bar_label(ax.containers[7],padding=3)
ax.bar_label(ax.containers[7],labels='n='+successfulDomainsAtRanks.astype('string'),padding=2, rotation=0, size=7)
# ax.set_ylim(0,1800)
ax.set_ylim(top=1)

# plt.tight_layout(pad=0)
# fig.set_tight_layout(True)
saveFigure(fig,'filter_scan_cmp_details')
plt.show()

# %%
results.cmp_simplified_othered.value_counts() / results[~(results.cmp_simplified_othered.isna())].shape[0]
# Out:
# onetrust           0.435709
# other              0.182113
# quantcast          0.094085
# cookiebot          0.080999
# sourcepoint        0.071915
# funding choices    0.048881
# trustarc           0.044771
# google             0.041527
# Name: cmp_simplified_othered, dtype: float64
