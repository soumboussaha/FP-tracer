# %% [markdown]
# # Preparation and Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import glob
import os
from common import *
import json
from datetime import datetime
from matplotlib import ticker
from matplotlib.colors import LogNorm, Normalize
import seaborn as sns
import numpy as np
import jenkspy

#plt.style.use('thesis.mplstyle')

# %%
attribute_combinations_sink=pd.read_csv('combinationsPerSink.csv')
attribute_combinations_sink
# Out:
#                   domain              sinkHost      destinationHost  \
# 0       eastwestbank.com      eastwestbank.com         velobank.com
# 1              9hits.com             9hits.com            9hits.com
# 2             pronto.com        perimeterx.net         px-cloud.net
# 3            aaalive.com           aaalive.com          tongdun.net
# 4              tieba.com             baidu.com            baidu.com
# ...                  ...                   ...                  ...
# 330804       piano.or.jp  google-analytics.com      doubleclick.net
# 330805  edmundoptics.com         mtcaptcha.com        mtcaptcha.com
# 330806       edmunds.com           edmunds.com  adsafeprotected.com
# 330807       edmunds.com           edmunds.com      doubleclick.net
# 330808            009.am  google-analytics.com         009.xn--p1ai
#
#                                    attribute_combinations  count_of_attributes
# ...

# %%
attribute_combinations=pd.read_csv('attribute_combinations_entropyJoint.csv')
attribute_combinations
# Out:
#             domain       destinationHost  \
# 0           009.am          009.xn--p1ai
# 1           009.am  google-analytics.com
# 2           009.am            yandex.com
# 3        00web.net             00web.net
# 4        00web.net       doubleclick.net
# ...            ...                   ...
# 269806  zzz.com.ua  google-analytics.com
# 269807  zzz.com.ua      undefined.com.ua
# 269808  zzz.com.ua            zzz.com.ua
# 269809  zzzfun.com                 51.la
# 269810    zzzmh.cn             baidu.com
#
#                                    attribute_combinations   entropy
# 0                                     navigator.useragent  0.564534
# 1       navigator.language, screen.colordepth, screen....  0.796308
# 2       navigator.language, screen.width, screen.heigh...  0.738580
# 3                                     navigator.useragent  0.564534
# 4       navigator.useragent, history.length, screen.he...  0.763784
# ...

# %%
flowReport= pd.read_csv('MarkedEasyprivacy.csv')

flowReport
# Out:
#                domain  page               destinationHost  \
# 0          google.com     2          google-analytics.com
# 1          google.com     2          google-analytics.com
# 2          google.com     2          google-analytics.com
# 3          google.com     2  smallbusiness.withgoogle.com
# 4          google.com     2          google-analytics.com
# ...               ...   ...                           ...
# 7554431  kyoto.travel     4                    google.com
# 7554432  kyoto.travel     4                    google.com
# 7554433  kyoto.travel     4                    google.com
# 7554434  kyoto.travel     4                    google.com
# 7554435  kyoto.travel     4                    google.com
#
#                       source            sourceHost                       sink  \
# 0         Navigator.language  googletagmanager.com  navigator.sendBeacon(url)
# 1               Screen.width  googletagmanager.com  navigator.sendBeacon(url)
# ...

# %% [markdown]
# # Load and Prepare Data
#
# ## Website Lists
#
# ### Tranco

# %%
tranco = pd.read_csv('tranco_top-1m_N7QVW_2022-10-07.csv',
                     names=['pagerank', 'domain']).iloc[0:500000, :]
tranco['rank_group'] = pd.cut(tranco.pagerank, bins=rank_group_bins)
tranco

# %% [markdown]
# ### sample example

# %% [markdown]
# ### Donothing crawl

# %%
#read parts and merge ( to be commented)

#RawStatus1= pd.read_json('outputs/statusReport_1.json')
#RawStatus2= pd.read_json('outputs/statusReport_2.json')
#RawStatus3= pd.read_json('outputs/statusReport_3.json')
#RawStatus4= pd.read_json('outputs/statusReport_4.json')
#RawStatus5= pd.read_json('outputs/statusReport_5.json')
#RawStatus6= pd.read_json('outputs/statusReport_6.json')
#RawStatus7= pd.read_json('outputs/statusReport_7.json')
#RawStatus8= pd.read_json('outputs/statusReport_8.json') 
#RawStatusG= pd.read_json('outputs/statusReport_G.json') 

#statusReport= pd.concat([RawStatus1, RawStatus2, RawStatus3, RawStatus4, RawStatus5, RawStatus6 ,RawStatus7 , RawStatus8 , RawStatusG ], ignore_index=True).drop_duplicates(ignore_index=True)

#statusReport.to_csv('raw_status.csv', index=False)

statusReport= pd.read_csv('raw_status.csv')
statusReport
# Out:
#                       domain                     start  \
# 0           gtld-servers.net  2023-03-31T11:48:04.212Z
# 1             akamaiedge.net  2023-03-31T11:48:04.214Z
# 2                 google.com  2023-03-31T11:48:04.196Z
# 3                  apple.com  2023-03-31T11:48:04.217Z
# 4              microsoft.com  2023-03-31T11:48:04.213Z
# ...                      ...                       ...
# 100082         easternct.edu  2023-04-17T09:17:57.572Z
# 100083          kyoto.travel  2023-04-17T09:17:55.481Z
# 100084     crosswordbuzz.com  2023-04-17T09:10:33.509Z
# 100085        williamhill.it  2023-04-17T09:19:33.822Z
# 100086  disposable-masks.xyz  2023-04-17T09:18:34.433Z
#
#                              end  hasErrors              error  \
# 0       2023-03-31T11:48:10.081Z       True        unreachable
# 1       2023-03-31T11:48:10.367Z       True        unreachable
# 2       2023-03-31T11:49:17.346Z      False         Successful
# ...

# %%
#read parts and merge ( to be commented)
#RawSummarizedFLow1 = pd.read_json('outputs/summarizedFlowReport_1.json')
#RawSummarizedFLow2 = pd.read_json('outputs/summarizedFlowReport_2.json')
#RawSummarizedFLow3 = pd.read_json('outputs/summarizedFlowReport_3.json')
#RawSummarizedFLow4 = pd.read_json('outputs/summarizedFlowReport_4.json')
#RawSummarizedFLow5 = pd.read_json('outputs/summarizedFlowReport_5.json')
#RawSummarizedFLow6 = pd.read_json('outputs/summarizedFlowReport_6.json')
#RawSummarizedFLow7 = pd.read_json('outputs/summarizedFlowReport_7.json')
#RawSummarizedFLow8 = pd.read_json('outputs/summarizedFlowReport_8.json')
#RawSummarizedFLowG = pd.read_json('outputs/summarizedFlowReport_G.json')

#flowReport  = pd.concat([RawSummarizedFLow1, RawSummarizedFLow2, RawSummarizedFLow3, RawSummarizedFLow4, RawSummarizedFLow5, RawSummarizedFLow6,RawSummarizedFLow7,RawSummarizedFLow8,RawSummarizedFLowG], ignore_index=False).drop_duplicates(ignore_index=True)

#save merge
#flowReport.to_csv('raw_flowreport.csv', index=False)
flowReport = pd.read_csv('raw_flowreport.csv')
flowReport.drop_duplicates(ignore_index=True)
# Out:
#                domain consentMode  page      pageHost  \
# 0          google.com   doNothing     2    google.com
# 1          google.com   doNothing     2    google.com
# 2          google.com   doNothing     2    google.com
# 3          google.com   doNothing     2    google.com
# 4          google.com   doNothing     2    google.com
# ...               ...         ...   ...           ...
# 7554431  kyoto.travel   doNothing     4  kyoto.travel
# 7554432  kyoto.travel   doNothing     4  kyoto.travel
# 7554433  kyoto.travel   doNothing     4  kyoto.travel
# 7554434  kyoto.travel   doNothing     4  kyoto.travel
# 7554435  kyoto.travel   doNothing     4  kyoto.travel
#
#                             frameHost               destinationHost  \
# 0        smallbusiness.withgoogle.com          google-analytics.com
# 1        smallbusiness.withgoogle.com          google-analytics.com
# 2        smallbusiness.withgoogle.com          google-analytics.com
# ...

# %%
# .astype({'hasBanner':'bool'})
#statusReport= pd.merge( tranco, statusReport,on='domain').drop_duplicates(subset=['domain'])
#statusReport=statusReport.drop_duplicates(ignore_index=True)
#statusReport.to_csv('raw_statsus_report_merged.csv', index=False)
statusReport = pd.read_csv('raw_statsus_report_merged.csv')
statusReport
# Out:
#        pagerank            domain       rank_group                     start  \
# 0             1        google.com       (0, 10000]  2023-03-31T11:48:04.196Z
# 1             2  gtld-servers.net       (0, 10000]  2023-03-31T11:48:04.212Z
# 2             3       youtube.com       (0, 10000]  2023-03-31T11:48:04.212Z
# 3             4      facebook.com       (0, 10000]  2023-03-31T11:48:04.213Z
# 4             5     microsoft.com       (0, 10000]  2023-03-31T11:48:04.213Z
# ...         ...               ...              ...                       ...
# 99995     99996       mrbasic.com  (90000, 100000]  2023-04-19T03:13:32.851Z
# 99996     99997    chartmogul.com  (90000, 100000]  2023-04-19T03:13:43.615Z
# 99997     99998    blogpeople.net  (90000, 100000]  2023-04-19T03:13:54.055Z
# 99998     99999       thevore.com  (90000, 100000]  2023-04-19T03:14:03.456Z
# 99999    100000        sfmlab.com  (90000, 100000]  2023-04-19T03:14:12.643Z
#
# ...

# %%
#transform the date format
statusReport.start = pd.to_datetime(statusReport.start)
statusReport.end = pd.to_datetime(statusReport.end)

#add column named status and filter out successfull from unsuccessfull crawls and specify the crawler 
statusReport['status'] = 'error in Donothing crawl'
statusReport.loc[~(statusReport.hasErrors), 'status'] = 'successful'

# add comlumn simplified error
statusReport['statusSimplified'] = statusReport.error
statusReport.loc[statusReport.error == 'Successful', 'statusSimplified'] = 'successful'
statusReport.loc[statusReport.error == 'argtype error', 'statusSimplified'] = 'other crawler error'
statusReport.loc[statusReport.error == 'unspecified error', 'statusSimplified'] = 'other crawler error'
statusReport.loc[statusReport.error == 'domain skipped', 'statusSimplified'] = 'other crawler error'


#I am not sure what is this line doing
statusReport['rank_group'] = pd.cut(
    statusReport.pagerank, bins=rank_group_bins)


# Get the tld of the crawled website
statusReport['tld'] = statusReport.domain.str.split('.').str[-1]

statusReport
# Out:
#        pagerank            domain       rank_group  \
# 0             1        google.com       (0, 10000]
# 1             2  gtld-servers.net       (0, 10000]
# 2             3       youtube.com       (0, 10000]
# 3             4      facebook.com       (0, 10000]
# 4             5     microsoft.com       (0, 10000]
# ...         ...               ...              ...
# 99995     99996       mrbasic.com  (90000, 100000]
# 99996     99997    chartmogul.com  (90000, 100000]
# 99997     99998    blogpeople.net  (90000, 100000]
# 99998     99999       thevore.com  (90000, 100000]
# 99999    100000        sfmlab.com  (90000, 100000]
#
#                                  start                              end  \
# 0     2023-03-31 11:48:04.196000+00:00 2023-03-31 11:49:17.346000+00:00
# 1     2023-03-31 11:48:04.212000+00:00 2023-03-31 11:48:10.081000+00:00
# 2     2023-03-31 11:48:04.212000+00:00 2023-03-31 11:54:25.831000+00:00
# ...

# %%
reach=statusReport.pivot_table(values='domain',index='error',aggfunc='count',margins=True)

#saveLatexTable(reach, 'crawled_successfully.tex')

reach
# Out:
#                             domain
# error
# Successful                   80618
# Unkonw error in processing       2
# argtype error                  163
# domain skipped                  74
# timeout error                 1504
# unreachable                  15303
# unspecified error             2336
# All                         100000

# %%
statusReport.loc[ (statusReport.error != 'Successful'),'error'] = 'scanning error'
statusReport.loc[(statusReport.error != 'Successful'),'statusSimplified'] = 'scanning error'

reach=statusReport.pivot_table(values='domain',index='error',aggfunc='count',margins=True)


#saveLatexTable(reach, 'crawled_successfully_error.tex')

reach
# Out:
#                 domain
# error
# Successful       80618
# scanning error   19382
# All             100000

# %% [markdown]
# ## Flows

# %%
#Remove malformed Destinations
flowReport.drop(flowReport.loc[flowReport.destinationHost.str.startswith('Malform') |flowReport.destinationHost.str.startswith('ERROR') |flowReport.destinationHost.str.startswith('malform') | flowReport.destinationHost.isnull()].index, inplace=True)

flowReport.drop(flowReport.loc[flowReport.destinationHost.str.startswith('UNKOWN') | flowReport.destinationHost.isnull()].index, inplace=True)

# add filtering ERROR.null.domain


# sink to source pairs
flowReport['transmission'] = flowReport.source + \
    ':' + flowReport.destinationHost

#flowReport.to_csv('flow_processsed.csv', index=False)

# %%
flowReport.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7554071 entries, 0 to 7554435
# Data columns (total 12 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   domain           object
#  1   consentMode      object
#  2   page             int64
#  3   pageHost         object
#  4   frameHost        object
#  5   destinationHost  object
#  6   source           object
#  7   sourceHost       object
#  8   sink             object
#  9   timeStamp        object
#  10  sinkHost         object
#  11  transmission     object
# dtypes: int64(1), object(11)
# memory usage: 749.2+ MB

# %%
pivot_table = flowReport.pivot_table(
    index=['domain', 'destinationHost'],
    values=['sourceHost', 'sinkHost'],
    aggfunc={'sourceHost': pd.Series.nunique, 'sinkHost': pd.Series.nunique}
)


# Reset the index to make the result look cleaner
pivot_table.reset_index(inplace=True)

pivot_table
# Out:
#             domain       destinationHost  sinkHost  sourceHost
# 0           009.am          009.xn--p1ai         1           1
# 1           009.am  google-analytics.com         1           1
# 2           009.am            yandex.com         1           2
# 3        00web.net             00web.net         1           1
# 4        00web.net       doubleclick.net         2           3
# ...            ...                   ...       ...         ...
# 269779  zzz.com.ua  google-analytics.com         1           1
# 269780  zzz.com.ua      undefined.com.ua         1           1
# 269781  zzz.com.ua            zzz.com.ua         1           1
# 269782  zzzfun.com                 51.la         1           1
# 269783    zzzmh.cn             baidu.com         1           1
#
# [269784 rows x 4 columns]

# %%
# mark as unknown if destination host is null
flowReport.loc[flowReport.destinationHost.isna(),
               'destinationHost'] = 'UNKNOWN'
flowReport.drop(flowReport.loc[flowReport.destinationHost.str.startswith('UNKOWN') | flowReport.destinationHost.isnull()].index, inplace=True)


#filter out first party
flowReport['destinationSimplified'] = flowReport.destinationHost
flowReport.loc[flowReport.destinationHost ==
               flowReport.pageHost, 'destinationSimplified'] = 'first-party'


#filter out first party in the sinkHOST
flowReport['HostSinkSimplified'] = flowReport.sinkHost
flowReport.loc[flowReport.sinkHost ==
               flowReport.pageHost, 'HostSinkSimplified'] = 'first-party'

flowReport.loc[(flowReport.sinkHost !=
               flowReport.pageHost) , 'HostSinkSimplified'] ='third-party'

flowReport.to_csv('flow_processsed.csv', index=False)

# %%
#flowReport = pd.read_csv('flow_processsed.csv')

# simplify the sink 
#flowReport['sinkSimplified'] = 'other'
#flowReport.loc[flowReport.sink.str.startswith('XML'),'sinkSimplified'] = 'XML HTTP Request'
#flowReport.loc[flowReport.sink.str.startswith('fetch'),'sinkSimplified'] = 'Fetch API'
#flowReport.loc[flowReport.sink.str.startswith('img.'),'sinkSimplified'] = 'image source'
#flowReport.loc[flowReport.sink.str.startswith('WebSocket'),'sinkSimplified'] = 'Web Socket'
#flowReport.loc[flowReport.sink.str.startswith('iframe'),'sinkSimplified'] = 'iFrame source'
#flowReport.loc[flowReport.sink.str.startswith('document.cookie'),'sinkSimplified'] = 'Cookie'
#flowReport.loc[flowReport.sink.str.startswith('script'),'sinkSimplified'] = 'script source'
#flowReport.loc[flowReport.sink.str.startswith('navigator.sendBeacon'),'sinkSimplified'] = 'sendBeacon()'

#flowReport.to_csv('flow_processsed.csv', index=False)


flowReport = pd.read_csv('flow_processsed.csv')

flowReport

# %% [markdown]
# ## summaryNumber of active sinks

# %%
flowReport.pivot_table(values='sink',index='sinkSimplified',aggfunc='count',margins=True).sort_values(by='sink', ascending=False)

# %%
#How many destinationHost are active in many domains

Most_active_destinations=flowReport.pivot_table(values='domain',index='destinationHost',aggfunc='count',margins=True).sort_values('domain', ascending=False)
Most_active_destinations.to_csv('Most_active_destinations.csv',index=True)
Most_active_destinations

# %%
Most_active_destinations = Most_active_destinations.iloc[1:31]
plt.bar(Most_active_destinations.index, Most_active_destinations['domain'])
plt.xlabel('Destination Domains')
plt.ylabel('Number of fingerprinting flows')
plt.title('Most Active Destinations')
plt.xticks(rotation=45 , ha='right', fontsize=6)
# Apply tight layout
# Add number on top of bars
for i, v in enumerate(Most_active_destinations['domain']):
    plt.text(Most_active_destinations.index[i], v + 1, str(v), ha='center', fontsize=3.5) # Increase font size of numbers on top of bars

plt.savefig('most_active_destinations.png', dpi=3000)
plt.show()

# %% [markdown]
# ### check the sources we were able to find

# %%
mosttranSources=flowReport.pivot_table(values='transmission',index='source',aggfunc='count',margins=True).sort_values('transmission', ascending=False)



#save file as CSV
mosttranSources.to_csv('most_active_attributes.csv',index=False)

#Generaate graph

#create a bar plot
ax = plt.subplot(111)
ax.bar(mosttranSources.index , mosttranSources['transmission'], width=0.2 )



# add labels manually
for i, v in enumerate(mosttranSources['transmission']):
    ax.text(i, v + 0.5, str(v), ha='center',  fontsize=3)

ax.set_xlim([-0.5, len(mosttranSources.index) - 0.5])
ax.set_xticks(np.arange(len(mosttranSources.index)))
ax.set_xticklabels(mosttranSources.index, rotation=0)



# set plot title and axis labels
plt.rcParams['font.family'] = 'sans-serif'

# set y-axis limit and plot title and axis labels
plt.title('Occurrences by Attribute')
plt.xlabel('Attribute' )
plt.ylabel('Occurrences')
plt.xticks(rotation=90, fontsize=5)
#change font to what is supported 
plt.rcParams['font.family'] = 'sans-serif'
plt.subplots_adjust()

 
# show the plot
plt.show()

# %%
attribute_combinations = flowReport.groupby(['domain','destinationHost'])['source'].apply(lambda x: list(x.unique())).reset_index(name='attribute_combinations')
attribute_combinations['count_of_attributes'] = attribute_combinations['attribute_combinations'].apply(lambda x: len(x.split('|')) if isinstance(x, str) else len(x))
attribute_combinations_sorted = attribute_combinations.sort_values('count_of_attributes', ascending=False)
attribute_combinations_sorted.to_csv('combinationsPerDestination.csv',index=False)
attribute_combinations_sorted

# %%
unique_attributes = attribute_combinations_sorted['attribute_combinations'].apply(lambda x: '|'.join(sorted(x))).drop_duplicates().reset_index(drop=True)
# Add a new column "num_attributes"

unique_attributes.to_csv('unique_combinations.csv',index=True)

# %%
unique_domains =flowReport.groupby('destinationHost')['domain'].nunique().sort_values( ascending=False)
unique_domains.to_csv('DestinationsSpread.csv',index=True)
unique_domains

# %% [markdown]
# ## Domain clustering

# %% [markdown]
# we will try to label the flowws but this time by considering that some domain might have the same owner

# %%
Cluster = pd.read_csv("output_clustering.csv")
Cluster
# Out:
#                                  URL  \
# 0                           yimg.com
# 1               googletagmanager.com
# 2               google-analytics.com
# 3                        gstatic.com
# 4                     cloudflare.com
# ...                              ...
# 54061         sunwingtravelgroup.com
# 54062                       mozu.com
# 54063  d3t95n9c6zzriw.cloudfront.net
# 54064            www.hs-heilbronn.de
# 54065                       notix.io
#
#                                                    Owner  \
# 0      {\n  "domain_name": [\n    "YIMG.COM",\n    "y...
# 1      {\n  "domain_name": [\n    "GOOGLETAGMANAGER.C...
# 2      {\n  "domain_name": [\n    "GOOGLE-ANALYTICS.C...
# 3      {\n  "domain_name": [\n    "GSTATIC.COM",\n   ...
# 4      {\n  "domain_name": "CLOUDFLARE.COM",\n  "regi...
# ...                                                  ...
# 54061  {\n  "domain_name": [\n    "SUNWINGTRAVELGROUP...
# ...

# %%
flowReport = pd.read_csv('flow_processsed_labled.csv')

flowReport['Label_cluster'] = 'other'

flowReport
# Out:
#                domain consentMode  page      pageHost  \
# 0          google.com   doNothing     2    google.com
# 1          google.com   doNothing     2    google.com
# 2          google.com   doNothing     2    google.com
# 3          google.com   doNothing     2    google.com
# 4          google.com   doNothing     2    google.com
# ...               ...         ...   ...           ...
# 7554066  kyoto.travel   doNothing     4  kyoto.travel
# 7554067  kyoto.travel   doNothing     4  kyoto.travel
# 7554068  kyoto.travel   doNothing     4  kyoto.travel
# 7554069  kyoto.travel   doNothing     4  kyoto.travel
# 7554070  kyoto.travel   doNothing     4  kyoto.travel
#
#                             frameHost               destinationHost  \
# 0        smallbusiness.withgoogle.com          google-analytics.com
# 1        smallbusiness.withgoogle.com          google-analytics.com
# 2        smallbusiness.withgoogle.com          google-analytics.com
# ...

# %%
merged_df = pd.merge(flowReport, Cluster, how='left', left_on='sinkHost', right_on='URL')
merged_df = merged_df.rename(columns={'Value': 'SinkOwner'})

merged_df
# Out:
#                domain consentMode  page      pageHost  \
# 0          google.com   doNothing     2    google.com
# 1          google.com   doNothing     2    google.com
# 2          google.com   doNothing     2    google.com
# 3          google.com   doNothing     2    google.com
# 4          google.com   doNothing     2    google.com
# ...               ...         ...   ...           ...
# 7554066  kyoto.travel   doNothing     4  kyoto.travel
# 7554067  kyoto.travel   doNothing     4  kyoto.travel
# 7554068  kyoto.travel   doNothing     4  kyoto.travel
# 7554069  kyoto.travel   doNothing     4  kyoto.travel
# 7554070  kyoto.travel   doNothing     4  kyoto.travel
#
#                             frameHost               destinationHost  \
# 0        smallbusiness.withgoogle.com          google-analytics.com
# 1        smallbusiness.withgoogle.com          google-analytics.com
# 2        smallbusiness.withgoogle.com          google-analytics.com
# ...

# %%
flowReport.pivot_table(values='transmission',index='source',aggfunc='count',margins=True)
# Out:
#                                       transmission
# source
# AudioContext.baseLatency                        29
# AudioContext.outputLatency                      28
# AudioDestinationNode.maxChannelCount           230
# AudioNode.channelCount                         212
# AudioNode.numberOfInputs                       212
# AudioNode.numberOfOutputs                      212
# BaseAudioContext.sampleRate                    269
# HTMLCanvasElement.toDataURL                  24861
# HTMLElement.offsetHeight                     13772
# HTMLElement.offsetWidth                      27504
# History.length                              199290
# Navigator.appCodeName                        24109
# Navigator.appName                            64540
# Navigator.appVersion                         19481
# Navigator.buildID                             8450
# Navigator.doNotTrack                         54429
# Navigator.hardwareConcurrency                57448
# ...

# %%
# print the flow report object
# Create a bar plot of the pivot table
pivot_table=flowReport.pivot_table(values='transmission',index='Label_cluster',aggfunc='count',margins=True).sort_values('transmission', ascending=False)

for i, v in enumerate(pivot_table['transmission']):
    plt.text(pivot_table.index[i], v + 1, str(v), ha='center', fontsize=5) # Increase font size of numbers on top of bars

plt.bar(pivot_table.index, pivot_table['transmission'])
plt.xlabel('Type of Flow')
plt.ylabel('Count of transmissions')
plt.title('Granuality of active fingerpriting flow on client side ')
plt.xticks(rotation=45 , ha='right', fontsize=8)


plt.savefig('granual_flows_whois.jpeg', dpi=3000)

plt.show()

# %% [markdown]
# # Key Numbers

# %% [markdown]
# ### Start, End, Duration

# %%
from datetime import datetime
crawlStart =  datetime.fromisoformat(statusReport.start.min().rstrip('Z'))
crawlEnd = datetime.fromisoformat( statusReport.loc[~(statusReport.end.isna()), 'end'].max().rstrip('Z'))
crawlDuration = crawlEnd-crawlStart
perDomainTime = crawlDuration/100000


crawlEndTime = statusReport.end.max() 

print('Crawl Start     ', crawlStart)
print('Crawl End       ', crawlEnd)
print('Crawl Duration  ', crawlDuration)

# %% [markdown]
# ### Successful, Unsuccessful

# %%
totalDomains = statusReport.shape[0]
successfulDomains = statusReport[~(statusReport.hasErrors)].shape[0]
errorDomains = statusReport[statusReport.hasErrors].shape[0]

print('Total Domain Count       ', totalDomains)
print('Successful Domain Count  ', successfulDomains)
print('Error Domain Count       ', errorDomains)

# %%
crawledDomainsAtRanks = statusReport.pivot_table(
    index='rank_group', aggfunc={'domain': 'count'}).domain
crawledDomainsAtRanks

# %%
successfulDomainsAtRanks = statusReport[~(statusReport.hasErrors)]\
    .pivot_table(index='rank_group', aggfunc={'domain': 'count'})\
    .domain
successfulDomainsAtRanks

# %%
statusReport

# %% [markdown]
# ### Page Counts

# %%
pagesPerDomain = flowReport.page.max() + 1
successfulPagesPerConsentMode = successfulDomains * pagesPerDomain
successfulPages = successfulPagesPerConsentMode * 1

print('Pages per Domain                   ', pagesPerDomain)
print('Successful Domain Count            ', successfulDomains)
print('Successful Pages per consent mode  ', successfulPagesPerConsentMode)
print('Successful Pages Overall           ', successfulPages)

# %% [markdown]
# ### Transmission Averages

# %% [markdown]
# ## Time and Progress

# %% [markdown]
# ## Status at Ranks

# %%
statusReport.error.value_counts()

# %% [markdown]
# ## Redirects

# %%
statusReport.pivot_table(index='error', columns=(
    statusReport.reachedDomain == statusReport.domain), aggfunc={'domain': 'count'})

# %%
redirects = statusReport.loc[~(
    statusReport.reachedDomain == statusReport.domain) & ~statusReport.hasErrors, :]
redirects.to_csv('redirects.csv')
redirects

# %% [markdown]
# # Validation

# %% [markdown]
# ### FT-inspector

# %%
FPspector= pd.read_csv("domain_pairs.csv")

print ("number of unique crawed top domains "+str(FPspector['Top Domain'].nunique()))
FPspector
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[171], line 1
# ----> 1 FPspector= pd.read_csv("domain_pairs.csv")
#       3 print ("number of unique crawed top domains "+str(FPspector['Top Domain'].nunique()))
#       4 FPspector
#
# File /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
# ...

# %%
merged_df = FPspector.merge(merged_df_flows, left_on="Top Domain", right_on="domain", how="inner")

# Create a new column to check the condition
merged_df["Condition"] = (merged_df["domain"] == merged_df["Top Domain"]) & (
    (merged_df["Script Domain"] == merged_df["sourceHost"]) | (merged_df["Script Domain"] == merged_df["sinkHost"])
)

# Convert boolean values to 1 or 0

merged_df["Condition"] = merged_df["Condition"].astype(int)


count = merged_df["Condition"].sum()
print("Count of flows :", count)


FP_SP=merged_df


FP_SP
# Out:
# Count of flows : 3160
#           Script Domain        Top Domain  \
# 0          g.alicdn.com          etao.com
# 1          g.alicdn.com          etao.com
# 2          g.alicdn.com          etao.com
# 3          g.alicdn.com          etao.com
# 4          g.alicdn.com          etao.com
# ...                 ...               ...
# 235462  x1.spideraf.com  inazumanews2.com
# 235463  x1.spideraf.com  inazumanews2.com
# 235464  x1.spideraf.com  inazumanews2.com
# 235465  x1.spideraf.com  inazumanews2.com
# 235466  x1.spideraf.com  inazumanews2.com
#
#                                                Script URL  \
# 0       https://g.alicdn.com/secdev/sufei_data/3.7.4/i...
# 1       https://g.alicdn.com/secdev/sufei_data/3.7.4/i...
# 2       https://g.alicdn.com/secdev/sufei_data/3.7.4/i...
# 3       https://g.alicdn.com/secdev/sufei_data/3.7.4/i...
# 4       https://g.alicdn.com/secdev/sufei_data/3.7.4/i...
# ...                                                   ...
# ...

# %%
num_unique_domains = FP_SP['domain'].nunique()
print("Number of unique domains:", num_unique_domains)

# Filter the DataFrame for each entropy level
high_fingerprinting_domains = FP_SP[FP_SP['entropy_level'] == 'High']['domain'].nunique()
mild_fingerprinting_domains = FP_SP[FP_SP['entropy_level'] == 'Low']['domain'].nunique()
medium_fingerprinting_domains = FP_SP[FP_SP['entropy_level'] == 'Medium']['domain'].nunique()

print("Number of unique domains with High Fingerprinting:", high_fingerprinting_domains)
print("Number of unique domains with Mild Fingerprinting:", mild_fingerprinting_domains)
print("Number of unique domains with Medium Fingerprinting:", medium_fingerprinting_domains)
# Out:
# Number of unique domains: 911
# Number of unique domains with High Fingerprinting: 479
# Number of unique domains with Mild Fingerprinting: 755
# Number of unique domains with Medium Fingerprinting: 858

# %%
# Filter the DataFrame to include only Medium or High Fingerprinting levels
filtered_df = FP_SP[(FP_SP['entropy_level'] == 'Medium Fingerprinting') | (FP_SP['entropy_level'] == 'High Fingerprinting')]

# Count the unique domains in the filtered DataFrame
unique_domains_count = filtered_df['domain'].nunique()

print("Number of unique domains with either Medium or High Fingerprinting level:", unique_domains_count)
# Out:
# Number of unique domains with either Medium or High Fingerprinting level: 891

# %%
matchingFPSpector = FP_SP[FP_SP["Condition"] == 1]
unique_domain_count = matchingFPSpector["Top Domain"].nunique()
print("Number of Unique Domains with Status 1:", unique_domain_count)

matchingFPSpector
# Out:
# Number of Unique Domains with Status 1: 71
#             Script Domain         Top Domain  \
# 1593         octopart.com       octopart.com
# 1594         octopart.com       octopart.com
# 1595         octopart.com       octopart.com
# 1610         octopart.com       octopart.com
# 1611         octopart.com       octopart.com
# ...                   ...                ...
# 234591        ostrovok.ru        ostrovok.ru
# 235059  nastypornpics.com  nastypornpics.com
# 235060  nastypornpics.com  nastypornpics.com
# 235061  nastypornpics.com  nastypornpics.com
# 235062  nastypornpics.com  nastypornpics.com
#
#                                                Script URL  \
# 1593    https://octopart.com/px/client/PX0Py5pczN/main...
# 1594    https://octopart.com/px/client/PX0Py5pczN/main...
# 1595    https://octopart.com/px/client/PX0Py5pczN/main...
# 1610    https://octopart.com/px/client/PX0Py5pczN/main...
# 1611    https://octopart.com/px/client/PX0Py5pczN/main...
# ...

# %%
num_unique_domains = matchingFPSpector['Script Domain'].nunique()
print("Number of unique domains:", num_unique_domains)

# Filter the DataFrame for each entropy level
high_fingerprinting_domains = matchingFPSpector[matchingFPSpector['entropy_level'] == 'High']['Script Domain'].nunique()
mild_fingerprinting_domains = matchingFPSpector[matchingFPSpector['entropy_level'] == 'Low']['Script Domain'].nunique()
medium_fingerprinting_domains = matchingFPSpector[matchingFPSpector['entropy_level'] == 'Medium']['Script Domain'].nunique()

print("Number of unique domains with High Fingerprinting:", high_fingerprinting_domains)
print("Number of unique domains with Mild Fingerprinting:", mild_fingerprinting_domains)
print("Number of unique domains with Medium Fingerprinting:", medium_fingerprinting_domains)


filtered_df =matchingFPSpector[(matchingFPSpector['entropy_level'] == 'Medium Fingerprinting') | (matchingFPSpector['entropy_level'] == 'High Fingerprinting')]

# Count the unique domains in the filtered DataFrame
unique_domains_count = filtered_df['Script Domain'].nunique()

print("Number of unique domains with either Medium or High Fingerprinting level:", unique_domains_count)
# Out:
# Number of unique domains: 71
# Number of unique domains with High Fingerprinting: 38
# Number of unique domains with Mild Fingerprinting: 27
# Number of unique domains with Medium Fingerprinting: 32
# Number of unique domains with either Medium or High Fingerprinting level: 58

# %%
df = matchingFPSpector
# Define a function to determine the highest fingerprinting level
def get_highest_fingerprinting_level(levels):
    if 'High' in levels.values:
        return 'High'
    elif 'Medium' in levels.values:
        return 'Medium'
    elif 'Mild' in levels.values:
        return 'Mild'
    else:
        return None

# Group by 'Script Domain' and apply the function to get the highest level
highest_levels = df.groupby('Script Domain')['entropy_level'].apply(get_highest_fingerprinting_level).reset_index()

# Count the number of each fingerprinting level
level_counts = highest_levels['entropy_level'].value_counts()

print("Number of URL Scripts with High Fingerprinting:", level_counts.get('High', 0))
print("Number of URL Scripts with Medium Fingerprinting:", level_counts.get('Medium', 0))
print("Number of URL Scripts with Mild Fingerprinting:", level_counts.get('Low', 0))
# Out:
# Number of URL Scripts with High Fingerprinting: 38
# Number of URL Scripts with Medium Fingerprinting: 20
# Number of URL Scripts with Mild Fingerprinting: 13

# %%
num_unique_domains = matchingFPSpector['Script URL'].nunique()
print("Number of unique domains:", num_unique_domains)
# Out:
# Number of unique domains: 78

# %% [markdown]
# ### Easy privacy matching

# %%
# Read the text file into a DataFrame
with open('easyprivacy_trackingservers_international.txt', 'r') as file:
    data = file.readlines()

# Extract domains and create a DataFrame
domains = [line.strip().split('^')[0].strip('||') for line in data if line.startswith('||')]
df = pd.DataFrame({'Domain': domains})

# Read the 'easyprivacyTrackers' DataFrame
easyprivacyTrackers = pd.read_csv("EasyprivacyTrackingServersList.csv")

# Combine the two DataFrames
combined_df = pd.concat([easyprivacyTrackers, df], ignore_index=True)

# Save the combined DataFrame to a CSV file
combined_df.to_csv('EasyprivacyTrackingServersList-Extended.csv', index=False)

# %%
combined_df
# Out:
#                Domain
# 0            00px.net
# 1           1cros.net
# 2     2022welcome.com
# 3            2cnt.net
# 4        2l6ddsmnm.de
# ...               ...
# 6700  adtimaserver.vn
# 6701         amcdn.vn
# 6702          ants.vn
# 6703   contineljs.com
# 6704       gostats.vn
#
# [6705 rows x 1 columns]

# %%
easyprivacyTrackers=pd.read_csv("EasyprivacyTrackingServersList.csv")

# Function to check if a domain is in the easyprivacyTrackers DataFrame
def check_if_in_easyprivacy(row):
    return any(domain in easyprivacyTrackers['Domain'].values for domain in [row['sinkHost']])

# Add 'Easyprivacy' column to flowReport
flowReport['Easyprivacy'] = flowReport.apply(check_if_in_easyprivacy, axis=1)

flowReport.to_csv("MarkedEasyprivacy.csv", index=False)

# %%
flowReport = pd.read_csv('MarkedEasyprivacy.csv')
easyprivacyTrackers = pd.read_csv("EasyprivacyTrackingServersList.csv")

# Function to check if a domain is in the easyprivacyTrackers DataFrame
def check_if_in_easyprivacy_Destination(row):
    return any(domain in easyprivacyTrackers['Domain'].values for domain in [row['destinationHost']])

# Add 'Easyprivacy' column to flowReport based on the function
flowReport['Easyprivacy_new'] = flowReport.apply(check_if_in_easyprivacy_Destination, axis=1)

# Perform XOR operation between existing 'Easyprivacy' and 'Easyprivacy_new' columns
flowReport['Easyprivacy'] = flowReport['Easyprivacy'] ^ flowReport['Easyprivacy_new']

# Drop the 'Easyprivacy_new' column if you no longer need it
flowReport = flowReport.drop(columns=['Easyprivacy_new'])

flowReport.to_csv("MarkedEasyprivacy.csv", index=False)

# %%
easyprivacyTrackers=pd.read_csv("MarkedEasyprivacy.csv")

# Filter the DataFrame where Easyprivacy is True
easyprivacy_true_domains = easyprivacyTrackers[easyprivacyTrackers['Easyprivacy']]

# Get the unique domains with Easyprivacy as True
unique_domains = easyprivacy_true_domains['domain'].unique()

# Print the total number of unique domains with Easyprivacy as True
print(f"Total number of unique domains with Easyprivacy as True: {len(unique_domains)}")

# Group the filtered DataFrame by entropy_level and count unique domains for each group
unique_domains_by_entropy = easyprivacy_true_domains.groupby('entropy_level')['domain'].nunique()

# Print the distribution of unique domains by entropy level
print("Distribution of unique domains with Easyprivacy as True by entropy level:")
print(unique_domains_by_entropy)
# Out:
# Total number of unique domains with Easyprivacy as True: 46011
# Distribution of unique domains with Easyprivacy as True by entropy level:
# entropy_level
# High           23747
# Low            37497
# Medium         11202
# Negligible1       31
# Negligible2      418
# very high       2164
# Name: domain, dtype: int64

# %%
# count he actual number of trackers in each category .


# Filter the DataFrame to have only Easyprivacy trackers that are True
filtered_df = easyprivacyTrackers[easyprivacyTrackers['Easyprivacy']]

# Extract pairs of entropy level/sourceHost and entropy level/sinkHost
source_host_pairs = filtered_df[['entropy_level', 'sourceHost']]
sink_host_pairs = filtered_df[['entropy_level', 'sinkHost']]

# Rename the columns
source_host_pairs.columns = ['entropy_level', 'tracker']
sink_host_pairs.columns = ['entropy_level', 'tracker']

# Combine both lists and remove duplicates
pairs_df = pd.concat([source_host_pairs, sink_host_pairs], ignore_index=True)
pairs_df = pairs_df.drop_duplicates()


# Load the list of domains from "EasyprivacyTrackingServersList.csv" into a DataFrame
tracking_servers = pd.read_csv("EasyprivacyTrackingServersList.csv")

# Merge the pairs DataFrame with the list of domains to mark if they match
merged_df = pairs_df.merge(tracking_servers, left_on='tracker', right_on='Domain', how='left')

# Mark as True if there's a match, otherwise mark as False
merged_df['matching'] = merged_df['tracker'].notna()

# Group by entropy level and count unique tracker domains that match in each group
grouped_df = merged_df.groupby('entropy_level')['matching'].sum()

# Print the result
print(grouped_df)
# Out:
# entropy_level
# High           4975
# Low            2593
# Medium         1883
# Negligible1      32
# Negligible2     201
# very high       546
# Name: matching, dtype: int64

# %% [markdown]
# ### AMI unique

# %%
AmIunique = pd.read_json('AMI_summarizedFlowReport.json')
AmIunique
# Out:
#                    domain consentMode  page       pageHost      frameHost  \
# 0              google.com   doNothing     3     google.com     google.com
# 1              google.com   doNothing     3     google.com     google.com
# 2              google.com   doNothing     4     google.com     google.com
# 3              google.com   doNothing     4     google.com     google.com
# 4              google.com   doNothing     4     google.com     google.com
# ..                    ...         ...   ...            ...            ...
# 988  www.amiunique.org/fp   doNothing     1  amiunique.org  amiunique.org
# 989     www.amiunique.org   doNothing     0  amiunique.org  amiunique.org
# 990     www.amiunique.org   doNothing     0  amiunique.org  amiunique.org
# 991     www.amiunique.org   doNothing     0  amiunique.org  amiunique.org
# 992     www.amiunique.org   doNothing     0  amiunique.org  amiunique.org
#
#      destinationHost               source            sourceHost  \
# ...

# %%
pivot_df = pd.pivot_table(AmIunique, index='source', aggfunc='size')
pivot_df.index
# Out:
# Index(['AudioDestinationNode.maxChannelCount', 'AudioNode.channelCount',
#        'AudioNode.numberOfInputs', 'AudioNode.numberOfOutputs',
#        'BaseAudioContext.sampleRate', 'HTMLCanvasElement.toDataURL',
#        'History.length', 'Navigator.appCodeName', 'Navigator.appName',
#        'Navigator.appVersion', 'Navigator.buildID', 'Navigator.doNotTrack',
#        'Navigator.hardwareConcurrency', 'Navigator.language',
#        'Navigator.maxTouchPoints', 'Navigator.oscpu', 'Navigator.platform',
#        'Navigator.product', 'Navigator.productSub', 'Navigator.userAgent',
#        'PermissionStatus.state', 'Screen.availHeight', 'Screen.availWidth',
#        'Screen.colorDepth', 'Screen.height', 'Screen.pixelDepth',
#        'Screen.width'],
#       dtype='object', name='source')

# %% [markdown]
# # Classification Joint_entropy

# %%
#Copy of sum_entrpy-unique_combi.csv
Entropy=pd.read_csv('entropy.csv')
# Convert attribute combinations in Entropy DataFrame to frozenset as well

Entropy
# Out:
#                                                  Vectors    joint_H  \
# 0                               AudioContext.baseLatency   2.459223
# 1                             AudioContext.outputLatency   0.000000
# 2                   AudioDestinationNode.maxChannelCount   0.229761
# 3                                 AudioNode.channelCount   0.000000
# 4                               AudioNode.numberOfInputs   0.000000
# ...                                                  ...        ...
# 15234  Navigator.maxTouchPoints|AudioContext.baseLate...  14.045911
# 15235  Navigator.userAgent|Navigator.doNotTrack|HTMLC...  13.127296
# 15236  Screen.width|Screen.height|Navigator.platform|...  11.354211
# 15237  Navigator.platform|Navigator.appName|Screen.wi...  13.966075
# 15238  Navigator.userAgent|Screen.height|Screen.width...  14.057875
#
#        joint_H_n     anon_set
# 0       0.290849   243.806268
# 1       0.000000     0.000000
# 2       0.056211  5033.882353
# ...

# %%
import pandas as pd

# Assuming Entropy DataFrame has columns: 'Vectors', 'joint_H', 'joint_H_n', 'anon_set'
# Assuming ranges and levels are defined as mentioned in the question

# Create a new column in Entropy DataFrame with categories based on 'joint_H_n' ranges
Entropy['level'] = pd.cut(Entropy['joint_H_n'], bins=[0.0,
 0.154098186,
 0.442675059,
 0.596961491,
 0.705353706,
 0.832438884,
 0.988612233], labels=['Negligible1','Negligible2', 'Low', 'Medium', 'High', 'very high'])

# Calculate the average anon_set per group
average_anon_set_per_group = Entropy.groupby('level')['anon_set'].mean().reset_index()

print(average_anon_set_per_group)
# Out:
#          level     anon_set
# 0  Negligible1  1613.127423
# 1  Negligible2  1994.229659
# 2          Low    31.866592
# 3       Medium    15.498721
# 4         High     5.127783
# 5    very high     2.562021

# %%
# Plot joint_H_n against anon_set with regression line
plt.figure(figsize=(8, 6))
sns.scatterplot(x='joint_H_n', y='anon_set', data=Entropy, hue='level', palette='viridis')

# Add regression line
sns.regplot(x='joint_H_n', y='anon_set', data=Entropy, scatter=False, color='black')

plt.title('joint_H_n vs anon_set with Regression Line')
plt.xlabel('joint_H_n')
plt.ylabel('anon_set')
plt.legend(title='Level')

plt.grid(True)
plt.show()

# %%
levels = ['Negligible', 'Low', 'Medium', 'High', 'very high']
line_colors = ['purple', 'green', 'yellow', 'orange', 'red']

# Filter out zero and negative values in 'anon_set'
filtered_entropy = Entropy[Entropy['anon_set'] > 0]

# Map the levels to a new merged 'Negligible' level
filtered_entropy['level_merged'] = filtered_entropy['level'].apply(lambda x: 'Negligible' if 'Negligible' in x else x)

# Plot joint_H_n against anon_set with regression line
plt.figure(figsize=(8, 6))
sns.scatterplot(x='joint_H_n', y='anon_set', data=filtered_entropy, hue='level_merged', palette=line_colors)

# Calculate the coefficients of the least squares line (linear regression)
x = filtered_entropy['joint_H_n']
y = filtered_entropy['anon_set']
coefficients = np.polyfit(x, np.log(y), 1)
m, c = coefficients

# Plot the least squares line
plt.plot(x, np.exp(m * x + c), color='black', linestyle='-', label='Least Squares Line')

plt.title('joint_H_n vs anon_set with Least Squares Line')
plt.xlabel('joint_H_n')
plt.ylabel('anon_set')
plt.legend(title='Level')

plt.yscale('log')  # Set y-axis to logarithmic scale
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_2822749/2918911298.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_entropy['level_merged'] = filtered_entropy['level'].apply(lambda x: 'Negligible' if 'Negligible' in x else x)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

levels = ['Negligible', 'Low', 'Medium', 'High', 'very high']
line_colors = ['purple', 'green', 'yellow', 'orange', 'red']

# Filter out zero and negative values in 'anon_set'
filtered_entropy = Entropy[Entropy['anon_set'] > 0]

# Map the levels to a new merged 'Negligible' level
filtered_entropy['level_merged'] = filtered_entropy['level'].apply(lambda x: 'Negligible' if 'Negligible' in x else x)

# Create a figure and axes
plt.figure(figsize=(8, 6))

# Scatter plot with smaller dots
sns.scatterplot(x='joint_H_n', y='anon_set', data=filtered_entropy, color='black', s=10)  # Set the size using 's'

# Calculate the coefficients of the least squares line (linear regression)
x = filtered_entropy['joint_H_n']
y = filtered_entropy['anon_set']
coefficients = np.polyfit(x, np.log(y), 1)
m, c = coefficients

# Plot the least squares line
plt.plot(x, np.exp(m * x + c), color='black', linestyle='-', label='Least Squares Line')

# Define your ranges
ranges = [(0.0, 0.442675059), (0.442675059, 0.596961491), (0.596961491, 0.705353706), (0.705353706, 0.832438884), (0.832438884, 0.988612233)]

# Plot shaded regions with the same color as the key
for i, (r, color) in enumerate(zip(ranges, line_colors)):
    plt.gca().add_patch(plt.Rectangle((r[0], 0), r[1] - r[0], plt.gca().get_ylim()[1], color=color, alpha=0.2, label=levels[i]))

# Set labels and title
plt.xlabel('Normalized Joint Entropy')
plt.ylabel('anonymaty set')
plt.legend(loc='upper right')
plt.yscale('log')  # Set y-axis to logarithmic scale
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_2822749/2746228094.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_entropy['level_merged'] = filtered_entropy['level'].apply(lambda x: 'Negligible' if 'Negligible' in x else x)

# %%
import matplotlib.pyplot as plt

# Plotting the histogram
n, bins, patches = plt.hist(Entropy["joint_H_n"], bins=20, edgecolor='black')  # Adjust the number of bins as needed
plt.xlabel('Entropy', fontsize=10)
plt.ylabel('Frequency', fontsize=10)
plt.title('Count of distributed entropy per unique combinations of fingerprinting attributes', fontsize=12)

# Adding text on top of each peak
for i in range(len(patches)):
    x = bins[i] + (bins[i+1] - bins[i]) / 2  # Calculate x-coordinate for the text
    y = n[i]  # Get the height of the current peak
    plt.text(x, y, str(int(y)), ha='center', va='bottom', fontsize=8)

# Modify x-axis ticks to show bin numbers
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)

# Display the histogram
plt.show()
plt.savefig('histogram_of_distributed_entropy_per_unique_combination.png', dpi=300)

# %%
attribute_combinations = flowReport.groupby(['domain','destinationHost'])['source'].apply(lambda x: list(x.unique())).reset_index(name='attribute_combinations')
attribute_combinations
# Out:
#             domain       destinationHost  \
# 0           009.am          009.xn--p1ai
# 1           009.am  google-analytics.com
# 2           009.am            yandex.com
# 3        00web.net             00web.net
# 4        00web.net       doubleclick.net
# ...            ...                   ...
# 269806  zzz.com.ua  google-analytics.com
# 269807  zzz.com.ua      undefined.com.ua
# 269808  zzz.com.ua            zzz.com.ua
# 269809  zzzfun.com                 51.la
# 269810    zzzmh.cn             baidu.com
#
#                                    attribute_combinations
# 0                                   [Navigator.userAgent]
# 1       [Navigator.language, Screen.colorDepth, Screen...
# 2       [Navigator.language, Screen.width, Screen.heig...
# 3                                   [Navigator.userAgent]
# 4       [Navigator.userAgent, History.length, Screen.h...
# ...                                                   ...
# ...

# %%
attribute_combinations['attribute_combinations'] = attribute_combinations['attribute_combinations'].astype(str)
attribute_combinations['attribute_combinations'] = attribute_combinations['attribute_combinations'].str.replace('[\[\]]', '', regex=True)
attribute_combinations['attribute_combinations'] = attribute_combinations['attribute_combinations'].str.replace("'", '', regex=True)


# Convert the 'attribute_combinations' column in attribute_combinations DataFrame to lowercase
attribute_combinations['attribute_combinations'] = attribute_combinations['attribute_combinations'].str.lower()

# Convert the 'attribute_combinations' column in Entropy DataFrame to lowercase
Entropy['Vectors'] = Entropy['Vectors'].str.lower()

# Create a new column in attribute_combinations DataFrame to store the matched entropy values
attribute_combinations['entropy'] = attribute_combinations['attribute_combinations'].apply(
    lambda x: Entropy.loc[Entropy['Vectors'].apply(
        lambda y: set(map(str.strip, y.split('|'))) == set(map(str.strip, x.split(','))))
    ]["joint_H_n"].iloc[0] if not pd.isna(x) and len(Entropy.loc[Entropy['Vectors'].apply(
        lambda y: set(map(str.strip, y.split('|'))) == set(map(str.strip, x.split(','))))
    ]["joint_H_n"]) > 0 else None
)

# Fill the NaN values in the entropy column with 0
attribute_combinations['entropy'] = attribute_combinations['entropy'].fillna(0)

# %%
# Save the modified DataFrame as a CSV file
attribute_combinations.to_csv('attribute_combinations_entropyJoint.csv', index=False)

# %%
df=attribute_combinations
# Assuming your DataFrame is named "df"
df['count'] = df['attribute_combinations'].apply(lambda x: len(x.split(',')))
df
# Out:
#             domain       destinationHost  \
# 0           009.am          009.xn--p1ai
# 1           009.am  google-analytics.com
# 2           009.am            yandex.com
# 3        00web.net             00web.net
# 4        00web.net       doubleclick.net
# ...            ...                   ...
# 269806  zzz.com.ua  google-analytics.com
# 269807  zzz.com.ua      undefined.com.ua
# 269808  zzz.com.ua            zzz.com.ua
# 269809  zzzfun.com                 51.la
# 269810    zzzmh.cn             baidu.com
#
#                                    attribute_combinations   entropy  count
# 0                                     navigator.useragent  0.564534      1
# 1       navigator.language, screen.colordepth, screen....  0.796308      5
# 2       navigator.language, screen.width, screen.heigh...  0.738580     13
# 3                                     navigator.useragent  0.564534      1
# 4       navigator.useragent, history.length, screen.he...  0.763784      7
# ...

# %%
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'attribute_combinations'

# Filter the DataFrame to exclude entropy equals 0
filtered_df = df[attribute_combinations['entropy'] > 0]

# Scatter plot of entropy vs count
plt.scatter(filtered_df['count'], filtered_df['entropy'], s=10, alpha=0.5)

# Set labels and title
plt.xlabel('Count')
plt.ylabel('Entropy')
plt.title('Entropy vs Count of finger-printing attributes')

# Show the plot
plt.show()

# Save the plot as an image
plt.savefig('Entropy_vs_Count_fingerprinting_attributes.png', dpi=300)

# %%
breaks = jenkspy.jenks_breaks(attribute_combinations['entropy'],6)
breaks
# Out:
# [0.0,
#  0.154098186,
#  0.442675059,
#  0.596961491,
#  0.705353706,
#  0.832438884,
#  0.988612233]

# %%
ranges = []
for i in range(len(breaks) - 1):
    ranges.append((breaks[i], breaks[i + 1]))

# Display the generated ranges
print(ranges)
# Out:
# [(0.0, 0.154098186), (0.154098186, 0.442675059), (0.442675059, 0.596961491), (0.596961491, 0.705353706), (0.705353706, 0.832438884), (0.832438884, 0.988612233)]

# %%
# Define the ranges and corresponding levels

levels = ['Negligible1','Negligible2', 'Low', 'Medium', 'High', 'very high']

# Extract bin edges from ranges
bins = [r[0] for r in ranges] + [ranges[-1][1]]

# Categorize the entropy values
attribute_combinations['entropy_level'] = pd.cut(attribute_combinations['entropy'], bins=bins, labels=levels, right=False)

# Print the updated DataFrame with the new entropy levels
attribute_combinations
# Out:
#             domain       destinationHost  \
# 0           009.am          009.xn--p1ai
# 1           009.am  google-analytics.com
# 2           009.am            yandex.com
# 3        00web.net             00web.net
# 4        00web.net       doubleclick.net
# ...            ...                   ...
# 269806  zzz.com.ua  google-analytics.com
# 269807  zzz.com.ua      undefined.com.ua
# 269808  zzz.com.ua            zzz.com.ua
# 269809  zzzfun.com                 51.la
# 269810    zzzmh.cn             baidu.com
#
#                                    attribute_combinations   entropy  count  \
# 0                                     navigator.useragent  0.564534      1
# 1       navigator.language, screen.colordepth, screen....  0.796308      5
# 2       navigator.language, screen.width, screen.heigh...  0.738580     13
# 3                                     navigator.useragent  0.564534      1
# 4       navigator.useragent, history.length, screen.he...  0.763784      7
# ...

# %%
levels = ['Negligible1','Negligible2', 'Low', 'Medium', 'High', 'very high']
line_colors = ['purple','blue','green','Yellow' ,'orange', 'Red' ,'purple']

# Create a histogram of the entropy values
plt.hist(attribute_combinations['entropy'], bins=45, edgecolor='black', alpha=0.5)

# Plot shaded regions with the same color as the key
for i, (r, color) in enumerate(zip(ranges, line_colors)):
    plt.gca().add_patch(plt.Rectangle((r[0], 0), r[1] - r[0], plt.gca().get_ylim()[1], color=color, alpha=0.2, label=levels[i]))

# Set labels and title
plt.xlabel('Normalized_Joint_Entropy')
plt.ylabel('detected attribute sets')


# Create custom legend entries for the shaded regions
plt.legend()

plt.grid(True)
plt.show()

# %%
# Combine 'Negligible1' and 'Negligible2' into 'Negligible'
levels = ['Negligible', 'Low', 'Medium', 'High', 'very high']
line_colors = ['purple', 'green', 'Yellow', 'orange', 'Red']

# Aggregate 'Negligible1' and 'Negligible2' into a single 'Negligible' category
negligible_range = (min(ranges[0][0], ranges[1][0]), max(ranges[0][1], ranges[1][1]))
ranges = [negligible_range] + ranges[2:]

# Create a histogram of the entropy values
plt.hist(attribute_combinations['entropy'], bins=45, edgecolor='black', alpha=0.5)

# Plot shaded regions with the same color as the key
for i, (r, color) in enumerate(zip(ranges, line_colors)):
    plt.gca().add_patch(plt.Rectangle((r[0], 0), r[1] - r[0], plt.gca().get_ylim()[1], color=color, alpha=0.2, label=levels[i]))

# Set labels and title
plt.xlabel('Normalized_Joint_Entropy')
plt.ylabel('detected attribute sets')

# Create custom legend entries for the shaded regions
plt.legend()

plt.grid(True)
plt.show()

# %%
levels = ['No Activity', 'Negligible', 'Low', 'Medium', 'High', 'Very High']
line_colors = ['grey', 'purple', 'green', 'yellow', 'orange', 'red']

# Combine 'Negligible1' and 'Negligible2' into 'Negligible'
ranges = [(0.0, 0.05621125), (0.05621125, 0.442675059), (0.442675059, 0.596961491), (0.596961491, 0.705353706), (0.705353706, 0.832438884), (0.832438884, 0.988612233)]

# Create a histogram of the entropy values
plt.hist(attribute_combinations['entropy'], bins=45, edgecolor='black', alpha=0.5)

# Plot shaded regions with the same color as the key
for i, (r, color) in enumerate(zip(ranges, line_colors)):
    plt.gca().add_patch(plt.Rectangle((r[0], 0), r[1] - r[0], plt.gca().get_ylim()[1], color=color, alpha=0.2, label=levels[i]))

# Set labels and title
plt.xlabel('Normalized_Joint_Entropy')
plt.ylabel('detected attribute sets')

# Create custom legend entries for the shaded regions
plt.legend()

plt.grid(True)
plt.show()

# %%
levels = ['Negligible', 'Low', 'Medium', 'High', 'Very High']

# Assuming 'attribute_combinations' DataFrame with 'domain', 'entropy', and 'fingerprinter' columns
total_domains = 80618  # Total number of domains

# Define the specified entropy level ranges
entropy_ranges = [0.0, 0.442675059, 0.596961491, 0.705353706, 0.832438884, 0.988612233]

# Count of domains falling into each entropy level range
entropy_counts = []
for i in range(len(entropy_ranges) - 1):
    lower_bound = entropy_ranges[i]
    upper_bound = entropy_ranges[i + 1]
    count = attribute_combinations[
        (attribute_combinations['entropy'] > lower_bound) & 
        (attribute_combinations['entropy'] <= upper_bound)
    ]['domain'].nunique()
    entropy_counts.append(count)

# Calculate prevalence rates for each entropy level
prevalence_rates = [(count / total_domains) * 100 for count in entropy_counts]

# Print prevalence rates for each level
for i in range(len(levels)):
    print(f"Prevalence Rate of domains with {levels[i]} fingerprinting: {prevalence_rates[i]:.2f}%")
# Out:
# Prevalence Rate of domains with Negligible fingerprinting: 5.75%
# Prevalence Rate of domains with Low fingerprinting: 58.99%
# Prevalence Rate of domains with Medium fingerprinting: 30.94%
# Prevalence Rate of domains with High fingerprinting: 61.49%
# Prevalence Rate of domains with Very High fingerprinting: 8.08%

# %%
total_domains = 80618  # Total number of domains
levels = ['Negligible1','Negligible2', 'Low', 'Medium', 'High', 'Very High']

# Create a dictionary to store prevalence rates for each level
prevalence_rates = {}

# Loop through the levels and ranges
for entropy_level, entropy_range in zip(levels, ranges):
    # Filter the data based on entropy range
    filtered_df = attribute_combinations[
        (attribute_combinations['entropy'] >= entropy_range[0]) &
        (attribute_combinations['entropy'] <= entropy_range[1])
    ]
 
    # Count of domains when domain is equal to destinationHost in the current entropy level
    same_domain_domains = filtered_df[filtered_df['domain'] == filtered_df['destinationHost']]['domain'].nunique()
    prevalence_rate_same_domain = (same_domain_domains / total_domains) * 100
    
    # Count of domains when domain is not equal to destinationHost in the current entropy level
    diff_domain_domains = filtered_df[filtered_df['domain'] != filtered_df['destinationHost']]['domain'].nunique()
    prevalence_rate_diff_domain = (diff_domain_domains / total_domains) * 100
    
    prevalence_rates[entropy_level] = {
        'Prevalence Rate with Same Domain': prevalence_rate_same_domain,
        'Prevalence Rate with Different Domain': prevalence_rate_diff_domain
    }

# Print the prevalence rates for each level
for entropy_level, rates in prevalence_rates.items():
    print(f"Entropy Level: {entropy_level}")
    print("Prevalence First party:", rates['Prevalence Rate with Same Domain'])
    print("Prevalence third party:", rates['Prevalence Rate with Different Domain'])
    print()
# Out:
# Entropy Level: Negligible1
# Prevalence First party: 0.1910243369967005
# Prevalence third party: 6.231858890074177
#
# Entropy Level: Negligible2
# Prevalence First party: 0.2145922746781116
# Prevalence third party: 5.119204147957032
#
# Entropy Level: Low
# Prevalence First party: 33.7939417995981
# Prevalence third party: 49.63159592150636
#
# Entropy Level: Medium
# Prevalence First party: 2.2141457242799376
# Prevalence third party: 29.962291299709744
#
# Entropy Level: High
# Prevalence First party: 12.15113250142648
# Prevalence third party: 58.63206728025999
#
# Entropy Level: Very High
# Prevalence First party: 2.8430375350418022
# Prevalence third party: 5.800193505172542

# %%
# Grouping by 'entropy_level' and finding the most recurrent attribute combination
most_recurrent_combinations = attribute_combinations.groupby('entropy_level')['attribute_combinations'].agg(lambda x: x.mode().iloc[0])

# Merge with the original DataFrame to retrieve entropy and count values
result = most_recurrent_combinations.reset_index().merge(attribute_combinations[['entropy', 'count', 'entropy_level']], on='entropy_level').drop_duplicates(subset=['entropy_level', 'attribute_combinations'])[['entropy_level', 'entropy', 'count', 'attribute_combinations']]

result
# Out:
#        entropy_level   entropy  count  \
# 0        Negligible1  0.000000      1
# 5349     Negligible2  0.313705      1
# 10499            Low  0.564534      1
# 128410        Medium  0.651570      3
# 162615          High  0.796308      5
# 262218     very high  0.913534     12
#
#                                                                                                                                                                                                                                                                                                                                                        attribute_combinations
# ...

# %%
# Find the row indices with the lowest count for each entropy_level group
min_count_indices = attribute_combinations.groupby('entropy_level')['count'].idxmin()

# Select rows with the highest entropy among the rows with the lowest count for each entropy_level
attribute_combinations_highest_entropy_lowest_count = attribute_combinations.loc[min_count_indices]

# Sort the selected rows by entropy in descending order
attribute_combinations_highest_entropy_lowest_count = attribute_combinations_highest_entropy_lowest_count.sort_values(by='entropy', ascending=False)

# Set Pandas display options to show the full contents of the 'attribute_combinations' column
pd.set_option('display.max_colwidth', None)

# Display the DataFrame attribute_combinations_highest_entropy_lowest_count
attribute_combinations_highest_entropy_lowest_count
# Out:
#                domain  destinationHost  \
# 87406    funkyimg.com  splunkcloud.com
# 2211    3rab-naar.com    3rab-naar.com
# 430    123animes.mobi   123animes.mobi
# 0              009.am     009.xn--p1ai
# 97            0xxx.ws     hcaptcha.com
# 5           00web.net     facebook.com
#
#                                                   attribute_combinations  \
# 87406  navigator.useragent, storageestimate.usage, storageestimate.quota
# 2211                    navigator.useragent, htmlcanvaselement.todataurl
# 430                                          htmlcanvaselement.todataurl
# 0                                                    navigator.useragent
# 97                                                    navigator.language
# 5                                                htmlelement.offsetwidth
#
#         entropy  count entropy_level
# 87406  0.907555      3     very high
# 2211   0.742828      2          High
# 430    0.637409      1        Medium
# ...

# %%
min_count_indices = attribute_combinations.groupby('entropy_level')['count'].idxmax()

# Select rows with the highest entropy among the rows with the lowest count for each entropy_level
attribute_combinations_highest_entropy_lowest_count = attribute_combinations.loc[min_count_indices]

# Sort the selected rows by entropy in descending order
attribute_combinations_highest_entropy_lowest_count = attribute_combinations_highest_entropy_lowest_count.sort_values(by='entropy', ascending=False)

# Set Pandas display options to show the full contents of the 'attribute_combinations' column
pd.set_option('display.max_colwidth', None)

# Display the DataFrame attribute_combinations_highest_entropy_lowest_count
attribute_combinations_highest_entropy_lowest_count
# Out:
#                        domain   destinationHost  \
# 67451        eastwestbank.com      velobank.com
# 38729             carters.com      px-cloud.net
# 16760          aroma-zone.com        botmind.io
# 198041       rueducommerce.fr  rueducommerce.fr
# 206838           shiseido.com     riskified.com
# 74706   ethiopianairlines.com        google.com
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      attribute_combinations  \
# ...

# %%
# Count the number of unique sink hosts per domain and destination host pairs
sink_host_unique_counts = flowReport.groupby(['domain', 'destinationHost'])['sinkHost'].nunique().reset_index(name='sinkHost')

# Merge the counts with the attribute_combinations DataFrame
merged_df = pd.merge(attribute_combinations, sink_host_unique_counts, on=['domain', 'destinationHost'], how='left')

# Display the merged DataFrame
merged_df
# Out:
#             domain       destinationHost  \
# 0           009.am          009.xn--p1ai
# 1           009.am  google-analytics.com
# 2           009.am            yandex.com
# 3        00web.net             00web.net
# 4        00web.net       doubleclick.net
# ...            ...                   ...
# 269806  zzz.com.ua  google-analytics.com
# 269807  zzz.com.ua      undefined.com.ua
# 269808  zzz.com.ua            zzz.com.ua
# 269809  zzzfun.com                 51.la
# 269810    zzzmh.cn             baidu.com
#
#                                                                                                                                                                                                                                                                 attribute_combinations  \
# ...

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Create a 3D figure
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Group the data by 'sinkHost' and 'entropy' and count the occurrences
grouped = merged_df.groupby(['sinkHost', 'entropy']).size().reset_index(name='count')

# Define a scaling factor for the dot size (you can adjust this as needed)
scaling_factor = 10

# Create a 3D scatter plot with dot size based on the count
ax.scatter(grouped['sinkHost'], grouped['entropy'], grouped['count'] * scaling_factor)

# Set labels for the axes
ax.set_xlabel('Number of sink Hosts')
ax.set_ylabel('Entropy Level')
ax.set_zlabel('Count')

# Set the title for the 3D plot
ax.set_title('Sink Host vs Entropy Level vs Count')

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Group the data by 'sinkHost' and 'entropy' and count the occurrences
grouped = merged_df.groupby(['sinkHost', 'entropy']).size().reset_index(name='count')

# Pivot the data to prepare for heatmap
pivot_data = grouped.pivot('sinkHost', 'entropy', 'count')

# Convert counts to logarithmic scale
pivot_data_log = np.log(pivot_data)

# Create a heatmap with log scale and without annotations
plt.figure(figsize=(10, 8))
sns.heatmap(pivot_data_log, cmap='YlGnBu', annot=False)
plt.xlabel('Entropy Level')
plt.ylabel('Number of sink Hosts')
plt.title('Sink Host vs Entropy Level (Log Scale)')
plt.show()
# Out:
# /tmp/ipykernel_2822749/4164583013.py:9: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   pivot_data = grouped.pivot('sinkHost', 'entropy', 'count')

# %% [markdown]
# ## Disconnect cross exanimation

# %%
Disconnect = pd.read_csv('DisconnectList.csv')
Disconnect
# Out:
#                   domain                                   category  \
# 0               00px.net  {'Advertising', 'FingerprintingInvasive'}
# 1     1-2-1marketing.com                        {'EmailAggressive'}
# 2          103092804.com                            {'Advertising'}
# 3               10web.io                                  {'Email'}
# 4          1q2w3.website                           {'Cryptomining'}
# ...                  ...                                        ...
# 3281            zune.com                                {'Content'}
# 3282            zune.net                                {'Content'}
# 3283        zymerget.bid                           {'Cryptomining'}
# 3284      zymerget.faith                           {'Cryptomining'}
# 3285        zypmedia.com                            {'Advertising'}
#
#       fingerprinter     fingerprintingLevel
# 0              True  FingerprintingInvasive
# 1             False             unspecified
# ...

# %%
# Count the number of rows where fingerprintingLevel is 'InvasiveFingerprinting'
invasive_count = Disconnect[Disconnect['fingerprintingLevel'] == 'FingerprintingInvasive'].shape[0]

# Count the number of rows where fingerprintingLevel is 'GeneralFingerprinting'
general_count = Disconnect[Disconnect['fingerprintingLevel'] == 'FingerprintingGeneral'].shape[0]

# Print the counts
print(f"Number of lines with fingerprintingLevel as 'InvasiveFingerprinting': {invasive_count}")
print(f"Number of lines with fingerprintingLevel as 'GeneralFingerprinting': {general_count}")
# Out:
# Number of lines with fingerprintingLevel as 'InvasiveFingerprinting': 110
# Number of lines with fingerprintingLevel as 'GeneralFingerprinting': 128

# %%
flowReport['disconnect'] = flowReport['domain'].isin(Disconnect['domain']) | \
                            flowReport['pageHost'].isin(Disconnect['domain']) | \
                            flowReport['destinationHost'].isin(Disconnect['domain']) | \
                            flowReport['sinkHost'].isin(Disconnect['domain'])
# Out:
#                domain  page               destinationHost  \
# 0          google.com     2          google-analytics.com
# 1          google.com     2          google-analytics.com
# 2          google.com     2          google-analytics.com
# 3          google.com     2  smallbusiness.withgoogle.com
# 4          google.com     2          google-analytics.com
# ...               ...   ...                           ...
# 7554431  kyoto.travel     4                    google.com
# 7554432  kyoto.travel     4                    google.com
# 7554433  kyoto.travel     4                    google.com
# 7554434  kyoto.travel     4                    google.com
# 7554435  kyoto.travel     4                    google.com
#
#                       source            sourceHost                       sink  \
# 0         Navigator.language  googletagmanager.com  navigator.sendBeacon(url)
# 1               Screen.width  googletagmanager.com  navigator.sendBeacon(url)
# ...

# %%
# Function to find matching domains in a row
def find_matching_domains(row):
    domains_found = set()

    if row['domain'] in Disconnect['domain'].values:
        domains_found.add(row['domain'])

    if row['destinationHost'] in Disconnect['domain'].values:
        domains_found.add(row['destinationHost'])

    if row['sinkHost'] in Disconnect['domain'].values:
        domains_found.add(row['sinkHost'])

    return domains_found

# Apply the function to create a new column
flowReport['matching_domains'] = flowReport.apply(find_matching_domains, axis=1)

# Display the DataFrame
# Out:
#                domain  page               destinationHost  \
# 0          google.com     2          google-analytics.com
# 1          google.com     2          google-analytics.com
# 2          google.com     2          google-analytics.com
# 3          google.com     2  smallbusiness.withgoogle.com
# 4          google.com     2          google-analytics.com
# ...               ...   ...                           ...
# 7554431  kyoto.travel     4                    google.com
# 7554432  kyoto.travel     4                    google.com
# 7554433  kyoto.travel     4                    google.com
# 7554434  kyoto.travel     4                    google.com
# 7554435  kyoto.travel     4                    google.com
#
#                       source            sourceHost                       sink  \
# 0         Navigator.language  googletagmanager.com  navigator.sendBeacon(url)
# 1               Screen.width  googletagmanager.com  navigator.sendBeacon(url)
# ...

# %%
# Create a column to store disconnect category, initially set to None
flowReport['disconnect_category'] = None

# Define conditions for each column
conditions = [
    flowReport['domain'].isin(Disconnect['domain']),
    flowReport['destinationHost'].isin(Disconnect['domain']),
    flowReport['sinkHost'].isin(Disconnect['domain'])
]

# Loop through rows and set disconnect category
for i, row in flowReport.iterrows():
    for condition, column in zip(conditions, ['domain', 'destinationHost', 'sinkHost']):
        if condition[i]:
            matching_domains = Disconnect[Disconnect['domain'] == row[column]]
            if not matching_domains.empty:
                flowReport.at[i, 'disconnect_category'] = matching_domains['category'].values[0]

# %%
# Assuming you have flowReport and attribute_combinations DataFrames

# Drop the 'entropy_level' column from flowReport
flowReport.drop(columns=['entropy_level'], inplace=True)

# Merge attribute_combinations into flowReport based on domain and destinationHost
merged_df = pd.merge(flowReport, 
                     attribute_combinations[['domain', 'destinationHost', 'entropy_level']], 
                     on=['domain', 'destinationHost'], 
                     how='left')

# Update the entropy_level column in flowReport where domain and destinationHost match
flowReport['entropy_level'] = merged_df['entropy_level']

# Convert the entropy_level column to string type
flowReport['entropy_level'] = flowReport['entropy_level'].astype(str)

# %%
flowReport.to_csv("flowreport_disconnectmarked.csv",index=False)

# %%
flowReport=pd.read_csv("flowreport_disconnectmarked.csv")

# %%
flowReport
# Out:
#                domain  page               destinationHost  \
# 0          google.com     2          google-analytics.com
# 1          google.com     2          google-analytics.com
# 2          google.com     2          google-analytics.com
# 3          google.com     2  smallbusiness.withgoogle.com
# 4          google.com     2          google-analytics.com
# ...               ...   ...                           ...
# 7554431  kyoto.travel     4                    google.com
# 7554432  kyoto.travel     4                    google.com
# 7554433  kyoto.travel     4                    google.com
# 7554434  kyoto.travel     4                    google.com
# 7554435  kyoto.travel     4                    google.com
#
#                       source            sourceHost                       sink  \
# 0         Navigator.language  googletagmanager.com  navigator.sendBeacon(url)
# 1               Screen.width  googletagmanager.com  navigator.sendBeacon(url)
# ...

# %%
# Group the DataFrame by 'entropy_level' and 'disconnect_category' and count unique domains
grouped = flowReport.groupby(['entropy_level', 'disconnect_category'])['domain'].nunique()

# Reset the index to get a DataFrame
result = grouped.reset_index()

# Print the result
result
# Out:
#     entropy_level                               disconnect_category  domain
# 0            High                                               nan   11983
# 1            High                          {'Advertising', 'Email'}      89
# 2            High          {'Advertising', 'FingerprintingGeneral'}     242
# 3            High         {'Advertising', 'FingerprintingInvasive'}    1017
# 4            High                                   {'Advertising'}    3531
# ..            ...                                               ...     ...
# 106     very high  {'FingerprintingGeneral', 'Disconnect', 'Email'}    1595
# 107     very high           {'FingerprintingInvasive', 'Analytics'}     258
# 108     very high                        {'FingerprintingInvasive'}     120
# 109     very high                         {'Social', 'Advertising'}      41
# 110     very high                                        {'Social'}      15
#
# [111 rows x 3 columns]

# %%
# Convert 'disconnect_category' column to string
df=flowReport
df['disconnect_category'] = df['disconnect_category'].astype(str)

# Rest of your code goes here...
# Categories to count
categories_to_count = ['FingerprintingInvasive','FingerprintingGeneral', 'Advertising', 'Analytics', 'Email', 'Content']

# Initialize a dictionary to store the results
results = {}
for category in categories_to_count:
    # Filter rows where the category is present and disconnect_category is not None
    df_filtered = df[df['disconnect_category'].apply(lambda x: x is not None and category in x)]

    if not df_filtered.empty:
        # Group by 'entropy_level' and count unique domains
        counts = df_filtered.groupby('entropy_level')['domain'].nunique()

        # Store the counts in the results dictionary
        results[category] = counts

# Convert the results to a DataFrame
result_df = pd.DataFrame(results).reset_index()

result_df
# Out:
#   entropy_level  FingerprintingInvasive  FingerprintingGeneral  Advertising  \
# 0          High                    1090                42083.0       5035.0
# 1           Low                     306                37319.0       8863.0
# 2        Medium                      16                 7834.0       4949.0
# 3   Negligible1                       3                 2417.0        324.0
# 4   Negligible2                      97                  579.0       1101.0
# 5           nan                       5                    NaN          NaN
# 6     very high                     430                 1599.0        624.0
#
#    Analytics    Email  Content
# 0     6187.0  41476.0  12967.0
# 1     4308.0  35936.0   9083.0
# 2     6327.0   8623.0   7960.0
# 3       49.0     24.0    759.0
# 4      141.0    145.0    622.0
# 5        NaN      NaN      NaN
# 6      644.0   1637.0    196.0

# %%
# Remove leading and trailing whitespaces and convert string sets to actual sets
flowReport['matching_domains'] = flowReport['matching_domains'].apply(lambda x: set(map(str.strip, x.strip('{}').split(','))))

# %%
flowReport['matching_domains']
# Out:
# 0          {'google-analytics.com', 'google.com'}
# 1          {'google-analytics.com', 'google.com'}
# 2          {'google-analytics.com', 'google.com'}
# 3          {'google-analytics.com', 'google.com'}
# 4          {'google-analytics.com', 'google.com'}
#                             ...
# 7554431                            {'google.com'}
# 7554432                            {'google.com'}
# 7554433                            {'google.com'}
# 7554434                            {'google.com'}
# 7554435                            {'google.com'}
# Name: matching_domains, Length: 7554436, dtype: object

# %%
# Initialize a dictionary to store the results
results = {}

# Iterate through each category
for category in categories_to_count:
    # Filter rows where the category is present and disconnect_category is not None
    df_filtered = flowReport[flowReport['disconnect_category'].apply(lambda x: x is not None and category in x)]
    
    # Initialize a defaultdict to store unique domains per entropy level and disconnect category
    unique_domains = defaultdict(lambda: defaultdict(set))
    
    # Iterate over each row in the filtered DataFrame
    for index, row in df_filtered.iterrows():
        entropy_level = row['entropy_level']
        disconnect_category = category
        
        # Retrieve the set of unique domains for the specific entropy level and disconnect category
        domains_set = row['matching_domains']
        
        # Update the set of unique domains for the specific entropy level and disconnect category
        unique_domains[entropy_level][disconnect_category].update(domains_set)
    
    # Initialize a defaultdict to store the counts of unique domains
    unique_domain_counts = defaultdict(lambda: defaultdict(int))
    
    # Count the number of unique domains for each entropy level and disconnect category
    for entropy_level, categories in unique_domains.items():
        for disconnect_category, domains_set in categories.items():
            unique_domain_counts[entropy_level][disconnect_category] = len(domains_set)
    
    # Store the counts in the results dictionary
    results[category] = pd.DataFrame(unique_domain_counts).T.reset_index().rename(columns={'index': 'entropy_level'})
    
    # Print the list of detected domains for each entropy level
    print(f"Category: {category}")
    for entropy_level, categories in unique_domains.items():
        print(f"Entropy Level: {entropy_level}")
        for disconnect_category, domains_set in categories.items():
            print(f"Disconnect Category: {disconnect_category}")
            print(f"Detected Domains: {domains_set}")
            print("\n")
# Out:
# Category: FingerprintingInvasive
# Entropy Level: High
# Disconnect Category: FingerprintingInvasive
# ...

# %%
from collections import defaultdict

# Initialize a dictionary to store the results
results = {}

# Initialize a defaultdict to store unique domains per category
unique_domains_category = defaultdict(lambda: defaultdict(set))

# Iterate through each category
for category in categories_to_count:
    # Filter rows where the category is present and disconnect_category is not None
    df_filtered = flowReport[flowReport['disconnect_category'].apply(lambda x: x is not None and category in x)]
    
    # Iterate over each row in the filtered DataFrame
    for index, row in df_filtered.iterrows():
        entropy_level = row['entropy_level']
        disconnect_category = category
        
        # Retrieve the set of unique domains for the specific category and entropy level
        domains_set = row['matching_domains']
        
        # Update the set of unique domains for the specific category and entropy level
        unique_domains_category[disconnect_category][entropy_level].update(domains_set)

# Process the unique domains for each category
for disconnect_category, entropy_levels in unique_domains_category.items():
    unique_domain_counts = defaultdict(int)
    for entropy_level, domains_set in entropy_levels.items():
        unique_domain_counts[entropy_level] = len(domains_set)
    
    # Store the counts in the results dictionary
    results[disconnect_category] = pd.DataFrame(unique_domain_counts.items(), columns=['entropy_level', 'unique_domains_count'])

    # Print the count of detected domains for each entropy level within the category
    print(f"Disconnect Category: {disconnect_category}")
    for entropy_level, count in entropy_levels.items():
        print(f"Entropy Level: {entropy_level}")
        print(f"Count of Unique Domains: {count}")
        print("\n")
# Out:
# Disconnect Category: FingerprintingInvasive
# Entropy Level: very high
# Count of Unique Domains: {"'breaktime.com.tw'", "'trendemon.com'", "'pixlee.com'", "'siftscience.com'", "'perimeterx.net'", "'bitmedia.io'", "'aweber.com'", "'fengkongcloud.com'", "'wayfair.com'", "'aamapiv2.com'", "'xiaoyuanzhao.com'", "'brightedge.com'", "'tongdun.net'", "'kitewheel.com'", "'mmapiws.com'", "'perfdrive.com'", "'guoshipartners.com'", "'b0e8.com'", "'fraudmetrix.cn'", "'clixtell.com'", "'flickr.com'", "'signifyd.com'", "'aamsitecertifier.com'", "'online-metrix.net'", "'maxmind.com'", "'onevision.com.tw'"}
#
#
# Entropy Level: High
# ...

# %%
from collections import Counter

# Categories to count
categories_to_count = ['FingerprintingInvasive', 'FingerprintingGeneral', 'Advertising', 'Analytics', 'Email', 'Content']

# Initialize a dictionary to store the results
results = {}
for category in categories_to_count:
    # Filter rows where the category is present and disconnect_category is not None
    df_filtered = flowReport[flowReport['disconnect_category'].apply(lambda x: x is not None and category in x)]

    if not df_filtered.empty:
        # Group by 'entropy_level' and combine sets of 'matching_domains' and count the total unique elements
        combined_domains = df_filtered.groupby('entropy_level')['matching_domains'].apply(lambda x: len(set().union(*x)))
        
        # Store the counts in the results dictionary
        results[category] = combined_domains

# Convert the results to a DataFrame
result_df = pd.DataFrame(results)
result_df.reset_index(inplace=True)
result_df
# Out:
#   entropy_level  FingerprintingInvasive  FingerprintingGeneral  Advertising  \
# 0          High                      26                  486.0        199.0
# 1           Low                      30                  467.0        260.0
# 2        Medium                      10                   84.0        154.0
# 3   Negligible1                       2                   17.0         28.0
# 4   Negligible2                       4                   13.0         74.0
# 5           nan                       1                    NaN          NaN
# 6     very high                      26                   17.0         64.0
#
#    Analytics  Email  Content
# 0      185.0  478.0    198.0
# 1      133.0  462.0    288.0
# 2      102.0   97.0    106.0
# 3        7.0    5.0     19.0
# 4       23.0    5.0     27.0
# 5        NaN    NaN      NaN
# 6       31.0   26.0     32.0

# %%
# Create CSV for domains when domain=destinationHost
same_domain_df = attribute_combinations[attribute_combinations['domain'] == attribute_combinations['destinationHost']]

P1=pd.DataFrame({'destinationHost': same_domain_df['destinationHost']})
P1.to_csv('same_domain_destinations.csv', index=False)

# Create CSV for host domains when hostdestination is different from domain
diff_domain_df =attribute_combinations[attribute_combinations['domain'] != attribute_combinations['destinationHost']]

P2=pd.DataFrame({'destinationHost': diff_domain_df['destinationHost']})
P2.to_csv('Diff_domain_destinations.csv', index=False)

# %%
Thirdparty_high =diff_domain_df[diff_domain_df['entropy_level']=='High']
P3=pd.DataFrame({'destinationHost': Thirdparty_high['destinationHost']})
P3.to_csv('Thirdparty_high_domain_destinations.csv', index=False)

# %%
Thirdparty_Med =diff_domain_df[diff_domain_df['entropy_level']=='Medium']
P4=pd.DataFrame({'destinationHost': Thirdparty_Med['destinationHost']})
P4.to_csv('Thirdparty_Med_domain_destinations.csv', index=False)
P4
# Out:
#              destinationHost
# 25      google-analytics.com
# 29           7yydstxt226.com
# 34          adnetwork.agency
# 42                 baidu.com
# 47                 baidu.com
# ...                      ...
# 269802  google-analytics.com
# 269803  google-analytics.com
# 269805             baidu.com
# 269809                 51.la
# 269810             baidu.com
#
# [32420 rows x 1 columns]

# %%
Thirdparty_low =diff_domain_df[diff_domain_df['entropy_level']=='Low']
P5=pd.DataFrame({'destinationHost': Thirdparty_low['destinationHost']})
P5.to_csv('Thirdparty_Mild_domain_destinations.csv', index=False)

# %%
Thirdparty_low = diff_domain_df[diff_domain_df['entropy_level'] == 'Low']

destination_host_counts = Thirdparty_low['destinationHost'].value_counts()
sorted_destination_hosts = destination_host_counts.sort_values(ascending=False)

top_3_destination_hosts = sorted_destination_hosts.head(3)
print("Top 3 Destination Hosts with Counts:")
for host, count in top_3_destination_hosts.items():
    print(f"Destination Host: {host}, Count: {count}")
# Out:
# Top 3 Destination Hosts with Counts:
# Destination Host: doubleclick.net, Count: 19346
# Destination Host: google.de, Count: 9266
# Destination Host: google.com, Count: 8311

# %%
Thirdparty_low =diff_domain_df[diff_domain_df['entropy_level']=='very high']
P5=pd.DataFrame({'destinationHost': Thirdparty_low['destinationHost']})
P5.to_csv('Thirdparty_Very_high_domain_destinations.csv', index=False)

# %%
Thirdparty_high = diff_domain_df[diff_domain_df['entropy_level'] == 'very high']

destination_host_counts_high = Thirdparty_high['destinationHost'].value_counts()
sorted_destination_hosts_high = destination_host_counts_high.sort_values(ascending=False)

top_3_destination_hosts_high = sorted_destination_hosts_high.head(3)
print("Top 3 Destination Hosts with Counts (Very High Entropy Level):")
for host, count in top_3_destination_hosts_high.items():
    print(f"Destination Host: {host}, Count: {count}")
# Out:
# Top 3 Destination Hosts with Counts (Very High Entropy Level):
# Destination Host: webgains.io, Count: 767
# Destination Host: baidu.com, Count: 233
# Destination Host: datadome.co, Count: 233

# %%
Thirdparty_high = diff_domain_df[diff_domain_df['entropy_level'] == 'High']

destination_host_counts_high = Thirdparty_high['destinationHost'].value_counts()
sorted_destination_hosts_high = destination_host_counts_high.sort_values(ascending=False)

top_3_destination_hosts_high = sorted_destination_hosts_high.head(3)
print("Top 3 Destination Hosts with Counts (Very High Entropy Level):")
for host, count in top_3_destination_hosts_high.items():
    print(f"Destination Host: {host}, Count: {count}")
# Out:
# Top 3 Destination Hosts with Counts (Very High Entropy Level):
# Destination Host: google-analytics.com, Count: 38294
# Destination Host: doubleclick.net, Count: 13614
# Destination Host: youtube.com, Count: 6746

# %%
Thirdparty_high = diff_domain_df[diff_domain_df['entropy_level'] == 'Medium']

destination_host_counts_high = Thirdparty_high['destinationHost'].value_counts()
sorted_destination_hosts_high = destination_host_counts_high.sort_values(ascending=False)

top_3_destination_hosts_high = sorted_destination_hosts_high.head(3)
print("Top 3 Destination Hosts with Counts (Very High Entropy Level):")
for host, count in top_3_destination_hosts_high.items():
    print(f"Destination Host: {host}, Count: {count}")
# Out:
# Top 3 Destination Hosts with Counts (Very High Entropy Level):
# Destination Host: google.com, Count: 7525
# Destination Host: google-analytics.com, Count: 6230
# Destination Host: baidu.com, Count: 1908

# %%
Firstparty_high =same_domain_df[same_domain_df['entropy_level']=='High']
P3=pd.DataFrame({'destinationHost': Firstparty_high['destinationHost']})
P3.to_csv('Firstparty_high_domain_destinations.csv', index=False)

Firstparty_Med =same_domain_df[same_domain_df['entropy_level']=='Medium']
P4=pd.DataFrame({'destinationHost': Firstparty_Med['destinationHost']})
P4.to_csv('Firstdparty_Med_domain_destinations.csv', index=False)

Firstparty_low =same_domain_df[same_domain_df['entropy_level']=='low']
P5=pd.DataFrame({'destinationHost': Firstparty_low['destinationHost']})
P5.to_csv('Firstparty_Mild_domain_destinations.csv', index=False)

# %%
Firstparty_high = same_domain_df[same_domain_df['entropy_level'] == 'High']
destination_host_counts_high = Firstparty_high['destinationHost'].value_counts()
sorted_destination_hosts_high = destination_host_counts_high.sort_values(ascending=False)

top_3_destination_hosts_high = sorted_destination_hosts_high.head(3)
print("Top 3 Destination Hosts with Counts (High Entropy Level):")
for host, count in top_3_destination_hosts_high.items():
    print(f"Destination Host: {host}, Count: {count}")
# Out:
# Top 3 Destination Hosts with Counts (High Entropy Level):
# Destination Host: 0rz.tw, Count: 1
# Destination Host: 10jqka.com.cn, Count: 1
# Destination Host: 13abc.com, Count: 1

# %%
Firstparty_med = same_domain_df[same_domain_df['entropy_level'] == 'Medium']
destination_host_counts_med = Firstparty_med['destinationHost'].value_counts()
sorted_destination_hosts_med = destination_host_counts_med.sort_values(ascending=False)

top_3_destination_hosts_med = sorted_destination_hosts_med.head(3)
print("Top 3 Destination Hosts with Counts (Medium Entropy Level):")
for host, count in top_3_destination_hosts_med.items():
    print(f"Destination Host: {host}, Count: {count}")
# Out:
# Top 3 Destination Hosts with Counts (Medium Entropy Level):
# Destination Host: 0daydown.com, Count: 1
# Destination Host: 9xbuddy.com, Count: 1
# Destination Host: 123moviesfree.net, Count: 1

# %%
Firstparty_low = same_domain_df[same_domain_df['entropy_level'] == 'Low']
destination_host_counts_low = Firstparty_low['destinationHost'].value_counts()
sorted_destination_hosts_low = destination_host_counts_low.sort_values(ascending=False)

top_3_destination_hosts_low = sorted_destination_hosts_low.head(3)
print("Top 3 Destination Hosts with Counts (Low Entropy Level):")
for host, count in top_3_destination_hosts_low.items():
    print(f"Destination Host: {host}, Count: {count}")
# Out:
# Top 3 Destination Hosts with Counts (Low Entropy Level):
# Destination Host: 00web.net, Count: 1
# Destination Host: 021.rs, Count: 1
# Destination Host: 0629.com.ua, Count: 1

# %%
Firstparty_low =same_domain_df[same_domain_df['entropy_level']=='Low']
P5=pd.DataFrame({'destinationHost': Firstparty_low['destinationHost']})
P5.to_csv('Firstparty_Mild_domain_destinations.csv', index=False)

# %%
Firstparty_high =same_domain_df[same_domain_df['entropy_level']=='very high']
P3=pd.DataFrame({'destinationHost': Firstparty_high['destinationHost']})
P3.to_csv('Firstparty_very_high_domain_destinations.csv', index=False)

# %%
##  Kmeans validation

# %%
# Specify the number of clusters (K)
K = 4

# Create a K-Means model
kmeans = KMeans(n_clusters=K, random_state=0)

# Fit the model to your data
kmeans.fit(attribute_combinations[['entropy']])

# Get the cluster labels for each data point
labels = kmeans.labels_

# Add cluster labels back to your original DataFrame
attribute_combinations['cluster_label'] = labels

# Initialize a dictionary to store cluster intervals
cluster_intervals = {}


attribute_combinations
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 5
#       2 K = 4
#       4 # Create a K-Means model
# ----> 5 kmeans = KMeans(n_clusters=K, random_state=0)
#       7 # Fit the model to your data
#       8 kmeans.fit(attribute_combinations[['entropy']])
#
# NameError: name 'KMeans' is not defined

# %%
attribute_combinations.rename(columns={'cluster_label': 'K-means labels'}, inplace=True)


attribute_combinations['K-means labels'].replace({0: 'Medium', 1: 'Low', 2: 'High'}, inplace=True)
attribute_combinations
# Out:
#             domain       destinationHost  \
# 0           009.am          009.xn--p1ai
# 1           009.am  google-analytics.com
# 2           009.am            yandex.com
# 3        00web.net             00web.net
# 4        00web.net       doubleclick.net
# ...            ...                   ...
# 269779  zzz.com.ua  google-analytics.com
# 269780  zzz.com.ua      undefined.com.ua
# 269781  zzz.com.ua            zzz.com.ua
# 269782  zzzfun.com                 51.la
# 269783    zzzmh.cn             baidu.com
#
#                                    attribute_combinations   entropy  \
# 0                                     navigator.useragent  0.051140
# 1       navigator.language, screen.colordepth, screen....  0.225225
# 2       navigator.language, screen.width, screen.heigh...  0.355329
# 3                                     navigator.useragent  0.051140
# 4       navigator.useragent, history.length, screen.he...  0.344368
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the Seaborn style and context
sns.set(style="whitegrid", context="notebook")

# Create two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Define a color palette for the dots based on fingerprinting activity level
palette = {'High': 'b', 'Low': 'g', 'Medium': 'r'}

# Plot the distribution of entropy based on 'entropy_level' with colored dots
sns.stripplot(x='entropy_level', y='entropy', data=attribute_combinations, ax=ax1, jitter=True, hue='entropy_level', palette=palette, alpha=0.7)
ax1.set_title('Distribution of Entropy by fingerprinting activity level')
ax1.set_xlabel('Jenks Natural Breaks algorithm')
ax1.set_ylabel('Entropy')

# Rotate the x-axis labels for better visibility
plt.setp(ax1.get_xticklabels(), rotation=45)

# Plot the distribution of entropy based on 'K-means labels' with colored dots
sns.stripplot(x='K-means labels', y='entropy', data=attribute_combinations, ax=ax2, jitter=True, hue='K-means labels', palette=palette, alpha=0.7)
ax2.set_title('Distribution of Entropy by K-means clustering')
ax2.set_xlabel('K-means clustering algorithm')
ax2.set_ylabel('Entropy')

# Rotate the x-axis labels for better visibility
plt.setp(ax2.get_xticklabels(), rotation=45)

# Adjust subplot layout
plt.tight_layout()
plt.legend(title='entropy_level', loc='upper left')
plt.show()

# %%
# Assuming 'flowReport' is your DataFrame
sub_df = flowReport[flowReport['entropy_level'] != 'negligent'].copy()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Your previous code to create grouped_source and define colors...

# Group the data by 'source', 'entropy_level', and count the occurrences
grouped_source = sub_df.groupby(['source', 'entropy_level']).size().unstack(fill_value=0)

# Get the unique 'source' categories
source_categories = grouped_source.index

# Set the width of each bar group
bar_width = 0.2

# Set the positions for the bars
positions = np.arange(len(source_categories))

# Define colors for 'low', 'medium', 'high', and 'very high' entropy levels
colors = {'Low': 'green', 'Medium': 'yellow', 'High': 'orange', 'very high': 'red'}

# Create a bar group for each 'entropy_level' category with appropriate colors
for i, entropy_level in enumerate(grouped_source.columns):
    if entropy_level in colors:  # Check if the entropy_level is in the colors dictionary
        counts = grouped_source[entropy_level]
        plt.bar(positions + i * bar_width * 1.2, counts, width=bar_width, label=entropy_level, color=colors[entropy_level])

plt.title("Count of transmissions per attribute per activity level on a logarithmic scale")
plt.xlabel('Active Sources')
plt.ylabel('Count (log scale)')
plt.yscale('log')  # Set the y-axis to a logarithmic scale
plt.gcf().set_size_inches(16, 6)  # Make the figure wider

# Set the x-axis tick labels without rotation
plt.xticks(positions + (len(grouped_source.columns) - 1) * bar_width * 1.2 / 2, source_categories, rotation=90)

# Create custom legend with color labels
legend_labels = [plt.Line2D([0], [0], color=colors[level], lw=4, label=level) for level in colors if level in grouped_source.columns]
plt.legend(legend_labels, [level for level in colors if level in grouped_source.columns], title='Entropy Level')
plt.tight_layout()
plt.show()

# %%
# Group the data by 'sink', 'entropy_level', and count the occurrences
grouped_sink = merged_df_flows.groupby(['sink', 'entropy_level']).size().unstack(fill_value=0)

# Get the unique 'sink' categories
sink_categories = grouped_sink.index

# Set the width of each bar group
bar_width = 0.2
# Define colors for 'low', 'medium', and 'high' entropy levels
colors = {'Low': 'green', 'Medium': 'orange', 'High': 'red'}
# Set the positions for the bars
positions = np.arange(len(sink_categories))

# Create a bar group for each 'entropy_level' category
for i, entropy_level in enumerate(grouped_sink.columns):
    counts = grouped_sink[entropy_level]
    plt.bar(positions + i * bar_width, counts, width=bar_width, label=entropy_level,color=colors[entropy_level])

plt.title("count of tranmistions per sink function per activity level")
plt.xlabel('Active Sinks')
plt.ylabel('Count ( log scale ) ')
plt.yscale('log')  # Set the y-axis to a logarithmic scale
plt.gcf().set_size_inches(16, 6)  # Make the figure wider

# Set the x-axis tick labels without rotation
plt.xticks(positions + (len(grouped_sink.columns) - 1) * bar_width / 2, sink_categories, rotation=90)

plt.legend(legend_labels, colors.keys(), title='Entropy Level')
plt.tight_layout()
plt.show()

# %%
# Group the data by 'source', 'entropy_level', and count the occurrences
grouped_source = sub_df.groupby(['source', 'entropy_level']).size().unstack(fill_value=0)

# Display the counts of different sources for each entropy level
print(grouped_source)
# Out:
# entropy_level                            High     Low  Medium  Negligible1  \
# source
# AudioContext.baseLatency                    0       0       1            0
# AudioContext.outputLatency                  0       0       0            0
# AudioDestinationNode.maxChannelCount        5       0       6            0
# AudioNode.channelCount                      5       0       1            0
# AudioNode.numberOfInputs                    5       0       1            0
# AudioNode.numberOfOutputs                   5       0       1            0
# BaseAudioContext.sampleRate                 5       0       6            0
# HTMLCanvasElement.toDataURL              2707       0     917            2
# HTMLElement.offsetHeight                 3769    3028     547         4583
# HTMLElement.offsetWidth                  3406    5520     515        16648
# History.length                         166972   23616    1921         1501
# ...

# %%
# Group the data by 'source', 'entropy_level', and count the occurrences
grouped_source = sub_df.groupby(['sink', 'entropy_level']).size().unstack(fill_value=0)

# Display the counts of different sources for each entropy level
print(grouped_source)
# Out:
# entropy_level                              High     Low  Medium  Negligible1  \
# sink
# WebSocket                                  4424     858     159            0
# WebSocket.send                             3694    6522    1361          224
# XMLHttpRequest.open(url)                1066413  135021   27766         1785
# XMLHttpRequest.send                      379113  106008  119767         1407
# XMLHttpRequest.setRequestHeader(value)   636471    3409     892          126
# document.cookie                          166299   71127    6888          354
# fetch.body                                21335   20914   23979           52
# fetch.url                                  9524    6330    1178           71
# iframe.src                               264536   82606   13641        11907
# img.src                                 1497281  263857  204190         6980
# img.srcset                                    6       0       0           27
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Group the data by 'sink', 'entropy_level', and count the occurrences
grouped_sink = merged_df_flows.groupby(['sink', 'entropy_level']).size().unstack(fill_value=0)

# Get the unique 'sink' categories
sink_categories = grouped_sink.index

# Set the width of each bar group
bar_width = 0.2

# Define colors for 'low', 'medium', and 'high' entropy levels
colors = {'Low': 'green', 'Medium': 'orange', 'High': 'red'}

# Set the positions for the bars
positions = np.arange(len(sink_categories))

# Create a bar group for each 'entropy_level' category

# Create a new figure for the subplots
plt.figure(figsize=(16, 6))

# Subplot 1: Logarithmic scale
plt.subplot(1, 2, 1)
for i, entropy_level in enumerate(grouped_sink.columns):
    counts = grouped_sink[entropy_level]
    plt.bar(positions + i * bar_width, counts, width=bar_width, label=entropy_level, color=colors[entropy_level])
plt.yscale('log')  # Set the y-axis to a logarithmic scale
plt.title("Count of transmissions per sink function per activity level (Logarithmic Scale)")
plt.xlabel('Active Sinks')
plt.ylabel('Count(log scale)')
plt.xticks(positions + (len(grouped_sink.columns) - 1) * bar_width / 2, sink_categories, rotation=90)
plt.legend(title='Entropy Level')

# Subplot 2: Normal scale
plt.subplot(1, 2, 2)
for i, entropy_level in enumerate(grouped_sink.columns):
    counts = grouped_sink[entropy_level]
    plt.bar(positions + i * bar_width, counts, width=bar_width, label=entropy_level, color=colors[entropy_level])
plt.title("Count of transmissions per sink function per activity level (Normal Scale)")
plt.xlabel('Active Sinks')
plt.ylabel('Count (Normal scale)')
plt.xticks(positions + (len(grouped_sink.columns) - 1) * bar_width / 2, sink_categories, rotation=90)
plt.legend(title='Entropy Level')

plt.tight_layout()

# Show both subplots
plt.show()

# %%
merged_df_flows.to_csv("Flows_withlevels.csv", index=False)

# %%
merged_df_flows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7554436 entries, 0 to 7554435
# Data columns (total 12 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   domain           object
#  1   consentMode      object
#  2   page             int64
#  3   pageHost         object
#  4   frameHost        object
#  5   destinationHost  object
#  6   source           object
#  7   sourceHost       object
#  8   sink             object
#  9   timeStamp        object
#  10  sinkHost         object
#  11  entropy_level    object
# dtypes: int64(1), object(11)
# memory usage: 1007.3+ MB

# %%
# Define the keywords for audio context fingerprinting
audio_context_keywords = [
    'AudioDestinationNode.maxChannelCount',
    'AudioNode.channelCount',
    'AudioNode.numberOfInputs',
    'AudioNode.numberOfOutputs',
    'BaseAudioContext.sampleRate',
]

# Initialize sets to store unique domains for each type of fingerprinting
audio_context_domains = set()
canvas_fingerprint_domains = set()

# Iterate through the DataFrame rows
for index, row in merged_df_flows.iterrows():
    source = row['source']
    domain = row['domain']

    # Check for AudioContext fingerprinting
    if any(keyword in source for keyword in audio_context_keywords):
        audio_context_domains.add(domain)

    # Check for Canvas fingerprinting
    if source == 'HTMLCanvasElement.toDataURL':
        canvas_fingerprint_domains.add(domain)

# Remove duplicates and count the number of unique domains
num_audio_context_domains = len(set(audio_context_domains))
num_canvas_fingerprint_domains = len(set(canvas_fingerprint_domains))

print("Number of domains where AudioContext fingerprinting is present:", num_audio_context_domains)
print("Number of domains with Canvas fingerprinting:", num_canvas_fingerprint_domains)
# Out:
# Number of domains where AudioContext fingerprinting is present: 54
# Number of domains with Canvas fingerprinting: 6237

# %%
# Define the keywords for audio context fingerprinting
storage_context_keywords = [
    'StorageEstimate.quota',
    'StorageEstimate.usage',
]

# Initialize sets to store unique domains for each type of fingerprinting
storage_domains = set()


# Iterate through the DataFrame rows
for index, row in merged_df_flows.iterrows():
    source = row['source']
    domain = row['domain']

    # Check for AudioContext fingerprinting
    if any(keyword in source for keyword in storage_context_keywords):
        storage_domains.add(domain)


# Remove duplicates and count the number of unique domains
storage_context_domains = len(set(storage_domains))

print("Number of domains with storage fingerprinting:", storage_context_domains)
# Out:
# Number of domains with storage fingerprinting: 148

# %% [markdown]
# # Third party scripts

# %%
import tldextract

# File paths for your JSON files
json_file_paths = ['thirdpartyscripts/ThirdpartyReport_4.json', 'thirdpartyscripts/ThirdpartyReport_3.json', 'thirdpartyscripts/ThirdpartyReport_2.json', 'thirdpartyscripts/ThirdpartyReport_1.json']

# Create an empty DataFrame to store the merged data
ScriptReport = pd.DataFrame()

# Loop through each JSON file and append its data to the merged DataFrame
for file_path in json_file_paths:
    # Read the JSON file into a DataFrame
    df = pd.read_json(file_path)

    # Append the DataFrame to the merged DataFrame
    ScriptReport = ScriptReport.append(df, ignore_index=True)
# Out:
# /tmp/ipykernel_3221123/1902145721.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ScriptReport = ScriptReport.append(df, ignore_index=True)
# /tmp/ipykernel_3221123/1902145721.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ScriptReport = ScriptReport.append(df, ignore_index=True)
# /tmp/ipykernel_3221123/1902145721.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ScriptReport = ScriptReport.append(df, ignore_index=True)
# /tmp/ipykernel_3221123/1902145721.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   ScriptReport = ScriptReport.append(df, ignore_index=True)

# %%
# Extract domain from 'sink' column and create a new 'domain' column using tldextract
def extract_domain(url):
    extracted = tldextract.extract(url)
    return f"{extracted.domain}.{extracted.suffix}"

ScriptReport['sinkHost'] = ScriptReport['sinkScript'].apply(extract_domain)

ScriptReport
# Out:
#              domain consentMode  page    pageHost destinationHost     sink  \
# 0        boohee.com   doNothing     0  boohee.com       baidu.com  img.src
# 1        boohee.com   doNothing     0  boohee.com       baidu.com  img.src
# 2        boohee.com   doNothing     1  boohee.com       baidu.com  img.src
# 3        boohee.com   doNothing     1  boohee.com       baidu.com  img.src
# 4        boohee.com   doNothing     2  boohee.com       baidu.com  img.src
# ...             ...         ...   ...         ...             ...      ...
# 2273598     bere.al   doNothing     0     bere.al         bere.al  img.src
# 2273599     bere.al   doNothing     0     bere.al         bere.al  img.src
# 2273600     bere.al   doNothing     0     bere.al         bere.al  img.src
# 2273601     bere.al   doNothing     0     bere.al         bere.al  img.src
# 2273602     bere.al   doNothing     0     bere.al         bere.al  img.src
#
# ...

# %%
attribute_combinations_sink=pd.read_csv('combinationsPerSink.csv')

# %%
merged_df = pd.merge(ScriptReport, attribute_combinations_sink[['domain', 'sinkHost', 'destinationHost', 'attribute_combinations']],
                     on=['domain', 'sinkHost', 'destinationHost'], how='left')

merged_df
# Out:
#              domain consentMode  page    pageHost destinationHost     sink  \
# 0        boohee.com   doNothing     0  boohee.com       baidu.com  img.src
# 1        boohee.com   doNothing     0  boohee.com       baidu.com  img.src
# 2        boohee.com   doNothing     1  boohee.com       baidu.com  img.src
# 3        boohee.com   doNothing     1  boohee.com       baidu.com  img.src
# 4        boohee.com   doNothing     2  boohee.com       baidu.com  img.src
# ...             ...         ...   ...         ...             ...      ...
# 2273598     bere.al   doNothing     0     bere.al         bere.al  img.src
# 2273599     bere.al   doNothing     0     bere.al         bere.al  img.src
# 2273600     bere.al   doNothing     0     bere.al         bere.al  img.src
# 2273601     bere.al   doNothing     0     bere.al         bere.al  img.src
# 2273602     bere.al   doNothing     0     bere.al         bere.al  img.src
#
# ...

# %%
ScriptReport = merged_df

# %%
ScriptReport = ScriptReport.drop_duplicates()

# %%
# Assuming your DataFrame is named 'df'
selected_columns = ['destinationHost', 'domain', 'entropy_level']
filtered_df = flowReport[selected_columns]

# Drop duplicates based on 'destinationHost' and 'domain'
unique_df = filtered_df.drop_duplicates(subset=['destinationHost', 'domain'])

# Print the resulting DataFrame
unique_df
# Out:
#                       destinationHost         domain entropy_level
# 0                google-analytics.com     google.com          High
# 3        smallbusiness.withgoogle.com     google.com           Low
# 9                     doubleclick.net     google.com           Low
# 26                          apple.com      apple.com           Low
# 64                      microsoft.com  microsoft.com     very high
# ...                               ...            ...           ...
# 7554288                     hotjar.io  easternct.edu           Low
# 7554342                    google.com   kyoto.travel        Medium
# 7554345                  kyoto.travel   kyoto.travel           Low
# 7554346          google-analytics.com   kyoto.travel          High
# 7554374                   youtube.com   kyoto.travel          High
#
# [269815 rows x 3 columns]

# %%
ScriptReport = pd.merge(ScriptReport, unique_df[['domain', 'destinationHost', 'entropy_level']],
                     on=['domain', 'destinationHost'], how='left')

ScriptReport
# Out:
#                domain consentMode  page      pageHost       destinationHost  \
# 0          boohee.com   doNothing     0    boohee.com             baidu.com
# 1          boohee.com   doNothing     1    boohee.com             baidu.com
# 2          boohee.com   doNothing     2    boohee.com             baidu.com
# 3          boohee.com   doNothing     3    boohee.com             baidu.com
# 4          boohee.com   doNothing     4    boohee.com             baidu.com
# ...               ...         ...   ...           ...                   ...
# 1123661  roseltorg.ru   doNothing     4  roseltorg.ru  google-analytics.com
# 1123662  roseltorg.ru   doNothing     4  roseltorg.ru  google-analytics.com
# 1123663  roseltorg.ru   doNothing     4  roseltorg.ru            yandex.com
# 1123664  roseltorg.ru   doNothing     4  roseltorg.ru            yandex.com
# 1123665  roseltorg.ru   doNothing     4  roseltorg.ru            comagic.ru
#
#                               sink  \
# ...

# %%
ScriptReport.to_csv("ScriptReport.csv",index=False)

# %%
ScriptReport.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1123666 entries, 0 to 1123665
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   domain                  1123666 non-null  object
#  1   consentMode             1123666 non-null  object
#  2   page                    1123666 non-null  int64
#  3   pageHost                1123666 non-null  object
#  4   destinationHost         1123649 non-null  object
#  5   sink                    1123666 non-null  object
#  6   sinkScript              1123666 non-null  object
#  7   sinkHost                1123666 non-null  object
#  8   attribute_combinations  1106420 non-null  object
#  9   entropy_level           1123625 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 94.3+ MB

# %%
# Step 1: Filter rows where sinkHost is different from domain
filtered_df = ScriptReport[ScriptReport['sinkHost'] != ScriptReport['domain']]

# %%
# Step 1: Filter rows where sinkHost is different from domain
filtered_df = ScriptReport[ScriptReport['sinkHost'] != ScriptReport['domain']]

# Step 2: Group by sinkScript and count the number of unique domains for each sinkScript
sinkScript_domain_counts = filtered_df.groupby('sinkScript')['domain'].nunique()

# Step 3: Convert the result into a DataFrame
result_df = sinkScript_domain_counts.reset_index(name='NumDomains')

# Display the resulting DataFrame
result_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100163 entries, 0 to 100162
# Data columns (total 2 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   sinkScript  100163 non-null  object
#  1   NumDomains  100163 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 1.5+ MB

# %%
import ast

# Make a copy of the DataFrame
ScriptReport_copy = ScriptReport.copy()

# Replace NaN values with an empty string
ScriptReport_copy['attribute_combinations'] = ScriptReport_copy['attribute_combinations'].fillna('')

# Convert the content of 'attribute_combinations' column from strings to sets
ScriptReport_copy['attribute_combinations'] = ScriptReport_copy['attribute_combinations'].apply(lambda x: set(ast.literal_eval(x)) if x else set())

# Display the updated DataFrame
print(ScriptReport_copy)
# Out:
#                domain consentMode  page      pageHost       destinationHost  \
# 0          boohee.com   doNothing     0    boohee.com             baidu.com
# 1          boohee.com   doNothing     1    boohee.com             baidu.com
# 2          boohee.com   doNothing     2    boohee.com             baidu.com
# 3          boohee.com   doNothing     3    boohee.com             baidu.com
# 4          boohee.com   doNothing     4    boohee.com             baidu.com
# ...               ...         ...   ...           ...                   ...
# 1123661  roseltorg.ru   doNothing     4  roseltorg.ru  google-analytics.com
# 1123662  roseltorg.ru   doNothing     4  roseltorg.ru  google-analytics.com
# 1123663  roseltorg.ru   doNothing     4  roseltorg.ru            yandex.com
# 1123664  roseltorg.ru   doNothing     4  roseltorg.ru            yandex.com
# 1123665  roseltorg.ru   doNothing     4  roseltorg.ru            comagic.ru
#
#                               sink  \
# ...

# %%
ScriptReport_copy
# Out:
#                domain consentMode  page      pageHost       destinationHost  \
# 0          boohee.com   doNothing     0    boohee.com             baidu.com
# 1          boohee.com   doNothing     1    boohee.com             baidu.com
# 2          boohee.com   doNothing     2    boohee.com             baidu.com
# 3          boohee.com   doNothing     3    boohee.com             baidu.com
# 4          boohee.com   doNothing     4    boohee.com             baidu.com
# ...               ...         ...   ...           ...                   ...
# 1123661  roseltorg.ru   doNothing     4  roseltorg.ru  google-analytics.com
# 1123662  roseltorg.ru   doNothing     4  roseltorg.ru  google-analytics.com
# 1123663  roseltorg.ru   doNothing     4  roseltorg.ru            yandex.com
# 1123664  roseltorg.ru   doNothing     4  roseltorg.ru            yandex.com
# 1123665  roseltorg.ru   doNothing     4  roseltorg.ru            comagic.ru
#
#                               sink  \
# ...

# %%
# Define a custom function to convert sets to frozensets and count unique frozensets
def count_unique_sets(group):
    return group['attribute_combinations'].apply(frozenset).nunique()

# Count the number of unique sets of attribute combinations per sinkScript
unique_sets_per_script = ScriptReport_copy.groupby('sinkScript').apply(count_unique_sets)

# Display the result
unique_sets_per_script
# Out:
# sinkScript
# blob:https://baomoi.com/21eb04e0-e909-4940-b3ad-5c64d7694aa3           1
# blob:https://baomoi.com/93998817-82ef-4899-a0ae-38e371a32310           1
# blob:https://baomoi.com/c6d016e9-6e02-4099-97e6-72c4b4573705           1
# blob:https://baomoi.com/d88ae066-8409-44bc-a3d2-c19d31e34f08           1
# blob:https://baomoi.com/dc4477bd-d831-4bc9-b8cb-231e3033ee1d           1
#                                                                       ..
# https://zyngapoker.com/static/20230331200831/stats.js                  1
# https://zyro.com/_nuxt/b04293e61.js                                    1
# https://zyro.com/_nuxt/e5f6aa590.js                                    1
# https://zzw.hsmdb.com/iwin_zzbweb-webapp/1.0.36/js/common/common.js    1
# self-hosted                                                            1
# Length: 125734, dtype: int64

# %%
import matplotlib.pyplot as plt

# Assign a name to the Series unique_sets_per_script
unique_sets_per_script.name = 'unique_sets_per_script'

# Merge the two DataFrames on 'sinkScript'
merged_df = pd.merge(result_df, unique_sets_per_script, on='sinkScript')

# Plot the relationship between 'NumDomains' and 'unique_sets_per_script'
plt.figure(figsize=(10, 6))
plt.scatter(merged_df['NumDomains'], merged_df['unique_sets_per_script'])
plt.title('Number of Domains vs. Count of Unique Attribute Combinations')
plt.xlabel('Number of Domains')
plt.ylabel('Count of Unique Attribute Combinations')
plt.grid(True)
plt.show()

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100163 entries, 0 to 100162
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   sinkScript              100163 non-null  object
#  1   NumDomains              100163 non-null  int64
#  2   unique_sets_per_script  100163 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 3.1+ MB

# %%
filtered_df = merged_df[(merged_df['unique_sets_per_script'] > 20) & (merged_df['NumDomains'] > 1)]
filtered_df
# Out:
#                                               sinkScript  NumDomains  \
# 5730    https://az416426.vo.msecnd.net/scripts/a/ai.0.js         228
# 7480   https://cdn.appdynamics.com/adrum/adrum-latest.js          26
# 7615          https://cdn.bizible.com/scripts/bizible.js         259
# 9641                    https://cdn.noibu.com/collect.js          79
# 11203  https://cdn.shopify.com/shopifycloud/shopify/a...         198
# 11341       https://cdn.trackjs.com/agent/v3/latest/t.js          26
# 11930  https://cdnjs.cloudflare.com/ajax/libs/rollbar...          17
# 17023                  https://eum.instana.io/eum.min.js         230
# 42953  https://script.hotjar.com/modules.69d367ac7af6...         176
# 42954  https://script.hotjar.com/modules.76304821fe35...          84
# 42969  https://script.hotjar.com/modules.f0ba8b655d2d...         113
# 50720  https://www.clarity.ms/eus-c-sc/s/0.7.6/clarit...        1276
# 50721          https://www.clarity.ms/s/0.7.6/clarity.js        1123
# ...

# %%
sorted_df = filtered_df.sort_values(by=['NumDomains', 'unique_sets_per_script'], ascending=[False, False])
sorted_df
# Out:
#                                               sinkScript  NumDomains  \
# 51231      https://www.google-analytics.com/analytics.js       38620
# 50720  https://www.clarity.ms/eus-c-sc/s/0.7.6/clarit...        1276
# 50721          https://www.clarity.ms/s/0.7.6/clarity.js        1123
# 7615          https://cdn.bizible.com/scripts/bizible.js         259
# 17023                  https://eum.instana.io/eum.min.js         230
# 5730    https://az416426.vo.msecnd.net/scripts/a/ai.0.js         228
# 11203  https://cdn.shopify.com/shopifycloud/shopify/a...         198
# 42953  https://script.hotjar.com/modules.69d367ac7af6...         176
# 50859  https://www.datadoghq-browser-agent.com/datado...         141
# 42969  https://script.hotjar.com/modules.f0ba8b655d2d...         113
# 42954  https://script.hotjar.com/modules.76304821fe35...          84
# 9641                    https://cdn.noibu.com/collect.js          79
# 50860  https://www.datadoghq-browser-agent.com/datado...          33
# ...

# %%
sorted_df.to_csv('Highly_common_configurable_scripts.csv', index=False)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(merged_df['NumDomains'], merged_df['unique_sets_per_script'],s=10)
#plt.title('Number of Domains vs. Count of Unique Attribute Combinations')
plt.xlabel('Number of Domains')
plt.ylabel('Count of Unique Attribute Combinations')
plt.xscale('log')

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(merged_df['NumDomains'], merged_df['unique_sets_per_script'], s=10)
plt.xlabel('Number of Domains')
plt.ylabel('Count of Unique Attribute Combinations')
plt.xscale('log')

plt.grid(True)

# Save the plot as a PDF
plt.savefig('scatter_plot.pdf')

plt.show()

# %%
ScriptReport_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1123666 entries, 0 to 1123665
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   domain                  1123666 non-null  object
#  1   consentMode             1123666 non-null  object
#  2   page                    1123666 non-null  int64
#  3   pageHost                1123666 non-null  object
#  4   destinationHost         1123649 non-null  object
#  5   sink                    1123666 non-null  object
#  6   sinkScript              1123666 non-null  object
#  7   sinkHost                1123666 non-null  object
#  8   attribute_combinations  1123666 non-null  object
#  9   entropy_level           1123625 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 94.3+ MB

# %%
ScriptReport_copy['first-party'] = ScriptReport_copy['domain'] == ScriptReport_copy['sinkHost']

# 2. Filter the dataframe
filtered_df = ScriptReport_copy[['sinkScript', 'first-party']].drop_duplicates()

# 3. Remove duplicated lines
filtered_df = filtered_df.drop_duplicates()

# 4. Print counts and rate
total_count = filtered_df.shape[0]
first_party_true_count = filtered_df[filtered_df['first-party'] == True].shape[0]
first_party_false_count = filtered_df[filtered_df['first-party'] == False].shape[0]

print("Counts:")
print("First Party True:", first_party_true_count)
print("First Party False:", first_party_false_count)

print("\nRates:")
print("First Party True Rate:", first_party_true_count / total_count)
print("First Party False Rate:", first_party_false_count / total_count)
# Out:
# Counts:
# First Party True: 26759
# First Party False: 100163
#
# Rates:
# First Party True Rate: 0.2108302737114133
# First Party False Rate: 0.7891697262885867

# %%
#qqtn.com
#baidu.com
attribute_combinations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269811 entries, 0 to 269810
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   domain                  269811 non-null  object
#  1   destinationHost         269811 non-null  object
#  2   attribute_combinations  269811 non-null  object
#  3   entropy                 269811 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 8.2+ MB

# %%
filtered_df = attribute_combinations[(attribute_combinations['domain'] == 'qqtn.com') & (attribute_combinations['destinationHost'] == 'baidu.com')]

filtered_df
# Out:
#           domain destinationHost  \
# 188192  qqtn.com       baidu.com
#
#                                    attribute_combinations   entropy
# 188192  screen.colordepth, screen.width, screen.height...  0.851491
